# %% [markdown]
# # **Case Study: Yelp Restaurant Recommendation System**
#
# ---------------
# ## **Introduction**
# ---------------
#
# **Yelp** was founded in **2004** to help people find **great local businesses**. Today, the website and their mobile application publish crowd-sourced reviews about local businesses as well as certain metadata about them that can help in customer's **decision-making process**. Yelp uses automated software to recommend the **most helpful** and **reliable reviews** for the Yelp community from such a large and diverse dataset.
#
# The Yelp dataset is a large collection of user reviews, business metadata, business check-ins, users' social network data, user tips for businesses across 10 cities spread across **4 countries**. The original dataset is very huge with ~ 11GB of data. In this case study, we will only use a subset of data due to the hardware limitations.
#
# -----------------
# ## **Objective**
# -----------------
#
# In this case study, I've implemented three types of recommendation systems:
# - **Knowledge/Rank Based recommendation system**
# - **Similarity-Based Collaborative filtering**
# - **Matrix Factorization Based Collaborative Filtering**
#
#
# -----------------
# ## **Dataset**
# -----------------
#
# Out of many attributes available in the yelp_reviews data, we will only use the following four attributes:
# - business_id
# - business_name
# - stars
# - user_id

# %%
# Mounting the drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## **Importing the necessary libraries and overview of the dataset**

# %%
# Used to ignore the warning given as output of the code
import warnings
warnings.filterwarnings('ignore')

# Basic libraries of python for numeric and dataframe computations
import numpy as np, pandas as pd

# Basic library for data visualization
import matplotlib.pyplot as plt

# Slightly advanced library for data visualization
import seaborn as sns

# A dictionary output that does not raise a key error
from collections import defaultdict

# A performance metrics in sklearn
from sklearn.metrics import mean_squared_error

# %%
yelp_review=pd.read_csv('yelp_reviews.csv',index_col=0)

# %%
yelp_review.head()
# Out:
#    business_blank              business_categories business_city  \
# 0           False  Breakfast & Brunch; Restaurants       Phoenix
# 1           False      Italian; Pizza; Restaurants       Phoenix
# 2           False      Middle Eastern; Restaurants         Tempe
# 3           False    Active Life; Dog Parks; Parks    Scottsdale
# 4           False                Tires; Automotive          Mesa
#
#                      business_full_address             business_id  \
# 0        6106 S 32nd St\nPhoenix, AZ 85042  9yKzy9PApeiPPOUJEtnvkg
# 1  4848 E Chandler Blvd\nPhoenix, AZ 85044  ZRJwVLyzEJq1VAihDhYiow
# 2     1513 E  Apache Blvd\nTempe, AZ 85281  6oRAC4uyJCsJl1X0WZpVSA
# 3   5401 N Hayden Rd\nScottsdale, AZ 85250  _1QQZuf4zZOyFCvXc0o6Vg
# 4        1357 S Power Road\nMesa, AZ 85206  6ozycU1RpktNG2-1BroVtw
#
#    business_latitude  business_longitude       business_name  \
# 0          33.390792         -112.012504  Morning Glory Cafe
# 1          33.305607         -111.978758  Spinato's Pizzeria
# 2          33.414345         -111.913031           Haji-Baba
# 3          33.522945         -111.907886  Chaparral Dog Park
# 4          33.391027         -111.684482       Discount Tire
#
#    business_neighborhoods  business_open  ...  reviewer_funny  reviewer_name  \
# 0                     NaN           True  ...             331          Jason
# 1                     NaN           True  ...               2           Paul
# 2                     NaN           True  ...               0         Nicole
# 3                     NaN           True  ...              18        lindsey
# 4                     NaN           True  ...               3          Roger
#
#   reviewer_review_count reviewer_type  reviewer_useful stars  \
# 0                   376          user             1034     5
# 1                     2          user                0     5
# 2                     3          user                3     4
# 3                    31          user               75     5
# 4                    28          user               32     5
#
#                                                 text    type  useful  \
# 0  My wife took me here on my birthday for breakf...  review       5
# 1  I have no idea why some people give bad review...  review       0
# 2  love the gyro plate. Rice is so good and I als...  review       1
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review       2
# 4  General Manager Scott Petello is a good egg!!!...  review       0
#
#                   user_id
# 0  rLtl8ZkDX5vH5nAx9C3q5Q
# 1  0a2KyEL0d3Yb1V6aivbIuQ
# 2  0hT2KtfLiobPvh6cDC8JQg
# 3  uZetl9T0NcROGOyFfughhg
# 4  vYmM4KTsC8ZfQBg-j5MWkw
#
# [5 rows x 31 columns]

# %% [markdown]
# ### **Loading the data**

# %%
# Importing the dataset
#yelp_review = pd.read_csv('/content/drive/MyDrive/ADSP/yelp/yelp_reviews.csv', usecols = ['user_id', 'business_id', 'business_name', 'stars'])

# Dropping the "business_name" column
data = yelp_review.drop("business_name", axis = 1)

# %% [markdown]
# Let's check the **info** of the data.

# %%
# This method is used to get the info of the dataframe.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229907 entries, 0 to 229906
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   business_blank          229907 non-null  bool
#  1   business_categories     229130 non-null  object
#  2   business_city           229907 non-null  object
#  3   business_full_address   229907 non-null  object
#  4   business_id             229907 non-null  object
#  5   business_latitude       229907 non-null  float64
#  6   business_longitude      229907 non-null  float64
#  7   business_neighborhoods  0 non-null       float64
#  8   business_open           229907 non-null  bool
#  9   business_review_count   229907 non-null  int64
#  10  business_stars          229907 non-null  float64
#  11  business_state          229907 non-null  object
#  12  business_type           229907 non-null  object
#  13  cool                    229907 non-null  int64
#  14  date                    229907 non-null  object
#  15  funny                   229907 non-null  int64
#  16  review_id               229907 non-null  object
#  17  reviewer_average_stars  229907 non-null  float64
#  18  reviewer_blank          229907 non-null  bool
#  19  reviewer_cool           229907 non-null  int64
#  20  reviewer_funny          229907 non-null  int64
#  21  reviewer_name           215879 non-null  object
#  22  reviewer_review_count   229907 non-null  int64
#  23  reviewer_type           229907 non-null  object
#  24  reviewer_useful         229907 non-null  int64
#  25  stars                   229907 non-null  int64
#  26  text                    229901 non-null  object
#  27  type                    229907 non-null  object
#  28  useful                  229907 non-null  int64
#  29  user_id                 229907 non-null  object
# dtypes: bool(3), float64(5), int64(9), object(13)
# memory usage: 49.8+ MB

# %% [markdown]
# - There are **2,29,907 rows** and **3 columns** in the data.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
data.head()
# Out:
#    business_blank              business_categories business_city  \
# 0           False  Breakfast & Brunch; Restaurants       Phoenix
# 1           False      Italian; Pizza; Restaurants       Phoenix
# 2           False      Middle Eastern; Restaurants         Tempe
# 3           False    Active Life; Dog Parks; Parks    Scottsdale
# 4           False                Tires; Automotive          Mesa
#
#                      business_full_address             business_id  \
# 0        6106 S 32nd St\nPhoenix, AZ 85042  9yKzy9PApeiPPOUJEtnvkg
# 1  4848 E Chandler Blvd\nPhoenix, AZ 85044  ZRJwVLyzEJq1VAihDhYiow
# 2     1513 E  Apache Blvd\nTempe, AZ 85281  6oRAC4uyJCsJl1X0WZpVSA
# 3   5401 N Hayden Rd\nScottsdale, AZ 85250  _1QQZuf4zZOyFCvXc0o6Vg
# 4        1357 S Power Road\nMesa, AZ 85206  6ozycU1RpktNG2-1BroVtw
#
#    business_latitude  business_longitude  business_neighborhoods  \
# 0          33.390792         -112.012504                     NaN
# 1          33.305607         -111.978758                     NaN
# 2          33.414345         -111.913031                     NaN
# 3          33.522945         -111.907886                     NaN
# 4          33.391027         -111.684482                     NaN
#
#    business_open  business_review_count  ...  reviewer_funny reviewer_name  \
# 0           True                    116  ...             331         Jason
# 1           True                    102  ...               2          Paul
# 2           True                    265  ...               0        Nicole
# 3           True                     88  ...              18       lindsey
# 4           True                      5  ...               3         Roger
#
#   reviewer_review_count  reviewer_type reviewer_useful  stars  \
# 0                   376           user            1034      5
# 1                     2           user               0      5
# 2                     3           user               3      4
# 3                    31           user              75      5
# 4                    28           user              32      5
#
#                                                 text    type  useful  \
# 0  My wife took me here on my birthday for breakf...  review       5
# 1  I have no idea why some people give bad review...  review       0
# 2  love the gyro plate. Rice is so good and I als...  review       1
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review       2
# 4  General Manager Scott Petello is a good egg!!!...  review       0
#
#                   user_id
# 0  rLtl8ZkDX5vH5nAx9C3q5Q
# 1  0a2KyEL0d3Yb1V6aivbIuQ
# 2  0hT2KtfLiobPvh6cDC8JQg
# 3  uZetl9T0NcROGOyFfughhg
# 4  vYmM4KTsC8ZfQBg-j5MWkw
#
# [5 rows x 30 columns]

# %%
data['stars']=data['stars'].astype('object')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229907 entries, 0 to 229906
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   business_blank          229907 non-null  bool
#  1   business_categories     229130 non-null  object
#  2   business_city           229907 non-null  object
#  3   business_full_address   229907 non-null  object
#  4   business_id             229907 non-null  object
#  5   business_latitude       229907 non-null  float64
#  6   business_longitude      229907 non-null  float64
#  7   business_neighborhoods  0 non-null       float64
#  8   business_open           229907 non-null  bool
#  9   business_review_count   229907 non-null  int64
#  10  business_stars          229907 non-null  float64
#  11  business_state          229907 non-null  object
#  12  business_type           229907 non-null  object
#  13  cool                    229907 non-null  int64
#  14  date                    229907 non-null  object
#  15  funny                   229907 non-null  int64
#  16  review_id               229907 non-null  object
#  17  reviewer_average_stars  229907 non-null  float64
#  18  reviewer_blank          229907 non-null  bool
#  19  reviewer_cool           229907 non-null  int64
#  20  reviewer_funny          229907 non-null  int64
#  21  reviewer_name           215879 non-null  object
#  22  reviewer_review_count   229907 non-null  int64
#  23  reviewer_type           229907 non-null  object
#  24  reviewer_useful         229907 non-null  int64
#  25  stars                   229907 non-null  object
#  26  text                    229901 non-null  object
#  27  type                    229907 non-null  object
#  28  useful                  229907 non-null  int64
#  29  user_id                 229907 non-null  object
# dtypes: bool(3), float64(5), int64(8), object(14)
# memory usage: 49.8+ MB

# %% [markdown]
# #### **Describe the distribution of ratings**

# %%
# Plotting distribution of ratings
plt.figure(figsize = (12, 5))
ax = sns.countplot(x = "stars", data = data)
plt.tick_params(labelsize = 10)
plt.title("Distribution of Ratings ", fontsize = 10)
plt.xlabel("Ratings", fontsize = 10)
plt.ylabel("Number of Ratings", fontsize = 10)
plt.show()

# %%
rating_count=pd.DataFrame(data['stars'].value_counts().reset_index())
rating_count.rename(columns={'index':'Rating','stars':'Count'},inplace=True)
rating_count.columns
# Out:
# Index(['Rating', 'Count'], dtype='object')

# %%
import plotly.express as px
fig=px.histogram(data,'stars')
fig.show()
# Out:
# <div>                            <div id="5ea263cc-1ad5-4f00-a7cb-79982a3659a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea263cc-1ad5-4f00-a7cb-79982a3659a6")) {                    Plotly.newPlot(                        "5ea263cc-1ad5-4f00-a7cb-79982a3659a6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"stars=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[5,5,4,5,5,4,5,4,4,5,5,5,5,4,4,2,3,5,3,4,3,5,5,1,5,4,5,4,4,4,5,1,5,4,3,1,4,4,4,4,4,4,4,4,4,3,5,3,4,4,4,5,4,4,5,4,2,4,4,5,4,1,3,4,1,1,5,5,4,5,4,1,4,4,5,4,4,4,5,1,4,4,5,4,1,4,5,4,5,1,1,5,4,4,4,5,4,4,5,5,4,5,5,4,3,1,5,3,5,4,2,5,5,1,3,4,3,3,4,1,4,5,5,4,5,5,1,5,3,2,3,3,4,4,5,3,1,2,5,4,1,4,4,3,5,5,3,2,1,5,3,4,5,3,5,5,3,5,5,2,5,5,2,2,5,1,5,3,4,4,1,3,2,3,4,4,5,5,5,3,5,3,5,5,5,5,4,4,5,5,1,4,4,5,3,4,2,3,4,5,5,5,5,4,4,5,5,4,1,4,3,3,1,5,4,5,4,5,2,4,4,3,5,3,4,2,5,5,5,5,4,4,2,3,1,2,4,2,5,1,3,5,4,2,5,4,4,4,4,3,3,5,2,5,5,4,4,2,5,5,5,4,5,4,5,4,5,3,3,4,5,4,4,3,4,3,5,4,5,5,3,1,3,2,5,5,3,1,3,1,3,2,1,5,4,5,4,4,5,1,4,3,4,4,4,4,3,5,2,3,4,5,4,3,4,4,5,2,3,3,4,1,3,2,5,4,4,4,3,3,3,5,2,5,5,4,4,4,1,5,5,5,3,2,4,3,3,5,2,4,5,3,5,5,5,5,4,5,4,4,5,5,4,2,2,5,4,3,5,5,4,4,5,1,4,2,4,5,3,5,5,1,5,4,4,5,5,4,4,1,5,2,3,4,1,1,5,3,3,5,4,4,5,3,5,1,2,1,4,4,5,4,4,2,2,5,4,3,3,5,5,5,3,5,5,5,2,3,2,2,5,5,4,3,1,4,1,2,4,1,5,4,4,5,2,5,4,5,4,3,5,5,5,5,4,3,4,1,4,5,5,5,4,3,5,4,4,2,1,3,4,5,1,5,5,4,5,5,4,5,4,5,2,2,4,3,4,1,1,4,4,4,5,5,2,4,4,4,3,5,5,2,5,4,5,2,5,1,1,5,3,4,5,4,2,4,5,2,5,4,4,5,4,3,2,2,4,3,1,3,4,3,4,5,3,4,5,5,4,4,2,4,4,5,1,4,4,5,4,3,4,4,4,5,5,5,4,4,4,1,4,3,5,1,3,3,3,4,4,5,5,5,5,3,5,1,4,5,4,3,3,5,4,5,4,5,4,3,1,4,2,5,4,4,5,3,4,3,4,5,5,2,2,4,5,4,1,4,5,1,5,2,4,3,2,4,4,5,5,5,5,4,4,2,4,4,5,4,4,5,5,5,5,4,4,5,5,3,4,5,4,5,4,4,3,4,5,4,2,4,3,5,3,4,5,4,5,3,3,3,5,3,2,4,3,5,1,5,5,4,4,1,5,3,4,3,2,4,1,5,5,4,4,5,5,4,2,2,2,4,1,2,4,4,4,4,5,3,3,4,2,4,4,4,5,5,4,1,3,4,5,5,4,5,1,1,5,5,2,5,4,2,4,3,5,3,2,4,5,5,5,4,4,2,5,4,2,5,5,4,5,5,2,4,4,5,3,4,5,1,5,5,1,1,5,2,1,3,3,4,4,4,5,5,4,1,3,1,2,3,2,4,2,1,4,3,4,5,1,5,5,4,4,3,5,5,4,2,4,5,4,4,5,5,5,2,2,5,5,2,3,5,2,5,4,1,4,4,4,4,5,3,4,5,4,3,5,5,4,3,2,5,5,5,3,5,4,4,4,3,4,5,4,4,2,3,4,4,3,4,5,5,1,3,1,4,3,3,5,5,4,1,4,4,5,2,5,5,5,4,5,4,5,3,4,4,3,3,5,5,5,4,3,4,1,4,4,5,5,4,5,5,2,4,2,4,5,5,4,3,5,5,5,4,5,4,3,3,5,4,5,4,5,4,3,5,2,5,4,2,5,5,1,5,5,5,4,4,3,4,4,5,4,4,5,5,5,5,1,5,5,4,3,4,5,5,4,4,4,4,4,3,1,1,1,5,5,5,1,5,4,4,4,4,3,5,4,4,4,5,1,3,1,4,5,4,3,2,3,4,4,2,2,4,5,4,4,4,3,1,5,3,5,1,4,5,4,4,5,5,5,5,4,3,3,1,5,2,5,5,4,4,2,4,4,3,4,3,4,4,4,5,5,5,4,3,4,2,5,5,4,1,5,3,2,1,5,5,5,5,2,2,5,4,4,5,4,5,4,5,4,3,4,2,5,5,5,2,1,5,4,4,5,1,5,4,5,5,5,5,5,4,3,1,4,4,3,3,4,5,4,4,5,2,5,5,4,4,5,4,3,4,1,3,4,4,5,5,4,3,4,3,4,3,5,4,5,4,4,1,4,4,5,4,3,5,4,4,4,5,5,4,5,5,4,1,1,5,5,5,4,5,5,3,5,4,2,2,2,3,4,4,4,4,5,4,5,5,5,4,5,5,4,3,2,5,1,2,4,4,4,5,2,4,1,3,5,5,5,1,3,4,4,3,4,5,5,5,2,5,5,5,5,5,3,1,4,5,5,3,3,2,2,4,2,3,2,1,2,5,5,3,4,4,5,4,5,4,2,5,5,5,1,5,2,5,4,1,5,3,4,4,1,3,4,3,2,5,3,5,3,4,5,5,4,5,1,1,4,5,3,2,4,3,4,5,2,2,4,4,4,2,5,1,3,5,3,2,2,5,2,3,1,5,5,4,4,5,5,5,5,4,4,5,4,5,5,4,5,4,1,5,5,2,3,4,2,4,4,4,5,4,5,2,3,5,4,5,5,5,2,1,4,4,5,3,4,1,4,1,4,5,4,5,5,5,5,5,3,5,4,5,1,5,5,4,5,4,3,5,5,5,3,5,4,4,3,4,5,3,4,5,4,1,4,4,4,4,4,2,3,5,5,5,2,5,3,4,4,4,4,4,4,5,4,5,2,4,5,5,5,5,3,5,5,4,4,2,4,5,2,5,1,5,5,3,4,5,5,5,4,4,4,2,4,1,4,4,4,3,5,5,4,3,3,5,4,3,4,3,4,4,4,4,5,2,1,1,4,2,3,4,5,3,5,4,4,4,1,5,4,2,2,1,5,4,4,4,4,3,3,5,4,4,5,2,4,5,5,4,4,5,2,5,5,5,5,5,3,5,4,3,5,4,4,5,5,4,5,4,5,4,5,2,4,5,5,1,4,3,2,2,3,5,5,4,4,5,3,5,4,5,4,4,3,4,4,3,4,4,4,3,2,5,2,4,5,5,5,4,4,4,5,3,5,3,4,1,2,5,4,3,4,3,5,3,4,1,4,5,2,4,5,3,4,5,5,1,5,4,5,5,1,3,4,4,4,5,4,3,2,3,5,5,2,4,3,4,5,4,4,5,4,4,5,4,4,5,3,4,3,4,5,1,3,1,4,4,5,5,3,5,5,4,5,5,4,5,4,5,5,4,4,4,2,3,5,4,5,5,4,4,3,5,4,3,5,4,4,3,4,3,4,5,4,3,5,2,1,5,5,5,5,4,2,5,3 ...

# %% [markdown]
# **Observations:**
#
# * The data seems to be **highly skewed** towards Rating **'4' and '5'**. Rating **'5'** is the second-highest in the count and nearly the same as the number of 4 rating count.
#
# * We can see very few people are giving ratings **between 1 to 3**. It shows people tend to **not give a rating** for a restaurant that they **don't like**.

# %% [markdown]
# ### Answering some basic business questions

# %% [markdown]
# #### **What is the total number of unique users and unique restaurants**?

# %%
# Number of unique users
data['user_id'].nunique()
# Out:
# 45981

# %%
# Number of unique restaurants
data['business_id'].nunique()
# Out:
# 11537

# %% [markdown]
# **Observations:**
# - There are **45,981 unique users** in the dataset.
# - There are **11,537 unique restaurants** in the dataset.
# - As per the number of unique users and restaurants, there is a **possibility of 45,981 * 11,537 = ~53 x 10^7 ratings** in the dataset. But **we only have 2,29,907 ratings**, i.e., not every user has rated every restaurant in the dataset. And we can build a recommendation system to recommend a restaurant to users which they have not visited.

# %% [markdown]
# #### **Is there any restaurant that has been visited more than once by the same user?**
# - If yes, then we should be taking average of the user's ratings.

# %%
data.groupby(['user_id','business_id']).count()
# Out:
#                                                business_blank  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw               1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw               1
#                        -sC66z4SO3tR7nFCjfQwuQ               1
#                        0vzZ_Bcb02rJljeMU9XkBw               1
#                        18TUn9oiW0k0yB6lheiOvw               1
# ...                                                       ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw               1
#                        ilJiRYZgxjrEu2iexKu-pQ               1
#                        sbsFamEj5wDxNAjUKrMcSw               1
#                        wP5849J1DKB2KS3M6UwOAg               1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q               1
#
#                                                business_categories  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                    1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                    1
#                        -sC66z4SO3tR7nFCjfQwuQ                    1
#                        0vzZ_Bcb02rJljeMU9XkBw                    1
#                        18TUn9oiW0k0yB6lheiOvw                    1
# ...                                                            ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                    1
#                        ilJiRYZgxjrEu2iexKu-pQ                    1
#                        sbsFamEj5wDxNAjUKrMcSw                    1
#                        wP5849J1DKB2KS3M6UwOAg                    1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                    1
#
#                                                business_city  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw              1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw              1
#                        -sC66z4SO3tR7nFCjfQwuQ              1
#                        0vzZ_Bcb02rJljeMU9XkBw              1
#                        18TUn9oiW0k0yB6lheiOvw              1
# ...                                                      ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw              1
#                        ilJiRYZgxjrEu2iexKu-pQ              1
#                        sbsFamEj5wDxNAjUKrMcSw              1
#                        wP5849J1DKB2KS3M6UwOAg              1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q              1
#
#                                                business_full_address  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                      1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                      1
#                        -sC66z4SO3tR7nFCjfQwuQ                      1
#                        0vzZ_Bcb02rJljeMU9XkBw                      1
#                        18TUn9oiW0k0yB6lheiOvw                      1
# ...                                                              ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                      1
#                        ilJiRYZgxjrEu2iexKu-pQ                      1
#                        sbsFamEj5wDxNAjUKrMcSw                      1
#                        wP5849J1DKB2KS3M6UwOAg                      1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                      1
#
#                                                business_latitude  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                  1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                  1
#                        -sC66z4SO3tR7nFCjfQwuQ                  1
#                        0vzZ_Bcb02rJljeMU9XkBw                  1
#                        18TUn9oiW0k0yB6lheiOvw                  1
# ...                                                          ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                  1
#                        ilJiRYZgxjrEu2iexKu-pQ                  1
#                        sbsFamEj5wDxNAjUKrMcSw                  1
#                        wP5849J1DKB2KS3M6UwOAg                  1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                  1
#
#                                                business_longitude  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                   1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                   1
#                        -sC66z4SO3tR7nFCjfQwuQ                   1
#                        0vzZ_Bcb02rJljeMU9XkBw                   1
#                        18TUn9oiW0k0yB6lheiOvw                   1
# ...                                                           ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                   1
#                        ilJiRYZgxjrEu2iexKu-pQ                   1
#                        sbsFamEj5wDxNAjUKrMcSw                   1
#                        wP5849J1DKB2KS3M6UwOAg                   1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                   1
#
#                                                business_neighborhoods  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                       0
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                       0
#                        -sC66z4SO3tR7nFCjfQwuQ                       0
#                        0vzZ_Bcb02rJljeMU9XkBw                       0
#                        18TUn9oiW0k0yB6lheiOvw                       0
# ...                                                               ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                       0
#                        ilJiRYZgxjrEu2iexKu-pQ                       0
#                        sbsFamEj5wDxNAjUKrMcSw                       0
#                        wP5849J1DKB2KS3M6UwOAg                       0
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                       0
#
#                                                business_open  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw              1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw              1
#                        -sC66z4SO3tR7nFCjfQwuQ              1
#                        0vzZ_Bcb02rJljeMU9XkBw              1
#                        18TUn9oiW0k0yB6lheiOvw              1
# ...                                                      ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw              1
#                        ilJiRYZgxjrEu2iexKu-pQ              1
#                        sbsFamEj5wDxNAjUKrMcSw              1
#                        wP5849J1DKB2KS3M6UwOAg              1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q              1
#
#                                                business_review_count  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                      1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                      1
#                        -sC66z4SO3tR7nFCjfQwuQ                      1
#                        0vzZ_Bcb02rJljeMU9XkBw                      1
#                        18TUn9oiW0k0yB6lheiOvw                      1
# ...                                                              ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                      1
#                        ilJiRYZgxjrEu2iexKu-pQ                      1
#                        sbsFamEj5wDxNAjUKrMcSw                      1
#                        wP5849J1DKB2KS3M6UwOAg                      1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                      1
#
#                                                business_stars  ...  \
# user_id                business_id                             ...
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw               1  ...
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw               1  ...
#                        -sC66z4SO3tR7nFCjfQwuQ               1  ...
#                        0vzZ_Bcb02rJljeMU9XkBw               1  ...
#                        18TUn9oiW0k0yB6lheiOvw               1  ...
# ...                                                       ...  ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw               1  ...
#                        ilJiRYZgxjrEu2iexKu-pQ               1  ...
#                        sbsFamEj5wDxNAjUKrMcSw               1  ...
#                        wP5849J1DKB2KS3M6UwOAg               1  ...
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q               1  ...
#
#                                                reviewer_cool  reviewer_funny  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw              1               1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw              1               1
#                        -sC66z4SO3tR7nFCjfQwuQ              1               1
#                        0vzZ_Bcb02rJljeMU9XkBw              1               1
#                        18TUn9oiW0k0yB6lheiOvw              1               1
# ...                                                      ...             ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw              1               1
#                        ilJiRYZgxjrEu2iexKu-pQ              1               1
#                        sbsFamEj5wDxNAjUKrMcSw              1               1
#                        wP5849J1DKB2KS3M6UwOAg              1               1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q              1               1
#
#                                                reviewer_name  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw              1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw              1
#                        -sC66z4SO3tR7nFCjfQwuQ              1
#                        0vzZ_Bcb02rJljeMU9XkBw              1
#                        18TUn9oiW0k0yB6lheiOvw              1
# ...                                                      ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw              1
#                        ilJiRYZgxjrEu2iexKu-pQ              1
#                        sbsFamEj5wDxNAjUKrMcSw              1
#                        wP5849J1DKB2KS3M6UwOAg              1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q              1
#
#                                                reviewer_review_count  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw                      1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw                      1
#                        -sC66z4SO3tR7nFCjfQwuQ                      1
#                        0vzZ_Bcb02rJljeMU9XkBw                      1
#                        18TUn9oiW0k0yB6lheiOvw                      1
# ...                                                              ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw                      1
#                        ilJiRYZgxjrEu2iexKu-pQ                      1
#                        sbsFamEj5wDxNAjUKrMcSw                      1
#                        wP5849J1DKB2KS3M6UwOAg                      1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q                      1
#
#                                                reviewer_type  reviewer_useful  \
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw              1                1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw              1                1
#                        -sC66z4SO3tR7nFCjfQwuQ              1                1
#                        0vzZ_Bcb02rJljeMU9XkBw              1                1
#                        18TUn9oiW0k0yB6lheiOvw              1                1
# ...                                                      ...              ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw              1                1
#                        ilJiRYZgxjrEu2iexKu-pQ              1                1
#                        sbsFamEj5wDxNAjUKrMcSw              1                1
#                        wP5849J1DKB2KS3M6UwOAg              1                1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q              1                1
#
#                                                stars  text  type  useful
# user_id                business_id
# --5hzxWLz5ozIg6OMo6tpQ Z3n01OZqARDv06QgBneOZw      1     1     1       1
# --65q1FpAL_UQtVZ2PTGew -q_VodbABJygOSuv86LOtw      1     1     1       1
#                        -sC66z4SO3tR7nFCjfQwuQ      1     1     1       1
#                        0vzZ_Bcb02rJljeMU9XkBw      1     1     1       1
#                        18TUn9oiW0k0yB6lheiOvw      1     1     1       1
# ...                                              ...   ...   ...     ...
# zztT9KKp0rmJRMeMl4CqzQ A8Khz3eeqIFFGaXurg3hxw      1     1     1       1
#                        ilJiRYZgxjrEu2iexKu-pQ      1     1     1       1
#                        sbsFamEj5wDxNAjUKrMcSw      1     1     1       1
#                        wP5849J1DKB2KS3M6UwOAg      1     1     1       1
# zzunUJtZqhcxDB3plnSFxg kuGQG_8i9P-4p9_Mym-G8Q      1     1     1       1
#
# [229906 rows x 28 columns]

# %%
# Find the sum of total ratings count by each user restaurant pair
data.groupby(['user_id', 'business_id']).count()['stars'].sum()
# Out:
# 229907

# %% [markdown]
# - The **sum is equal to the total number of observations** which implies **there is only interaction between a pair of restaurants and a user**.

# %% [markdown]
# #### **Which restaurant is the most reviewed restaurant in the dataset?**

# %%
data['business_id'].value_counts()
# Out:
# hW0Ne_HTHEAgGF1rAdmR-g    844
# VVeogjZya58oiTxK7qUjAQ    794
# JokKtdXU7zXHcr20Lrk29A    731
# ntN85eu27C04nwyPa8IHtw    679
# EWMwV5V9BxNs_U6nNVMeqw    645
#                          ...
# -NbEHP2GHFNb5PnmJnd4qQ      3
# QICgwHWhXIbihfcMKtws8g      3
# sAwxt4I4gTiL-08nyarJbg      3
# huzUWI5YqkJEEIudo0YiDg      3
# SeCVec3f91bEdosAILE4JA      3
# Name: business_id, Length: 11537, dtype: int64

# %% [markdown]
# **Observations:**
# - The **restaurant with business_id hW0Ne_HTHEAgGF1rAdmR-g  has been interacted by most users** which is **844** times.
# - But still, there is a possibility of **45,981-844 = 45,137** more interactions as we have **45,981** unique users in our dataset. For those  **remaining users**, a build recommendation system can be built to predict who is most likely to visit this restaurant.
#
# Also, out of these **844 interactions**, we need to consider the distribution of ratings as well to check whether this restaurant is the **most liked or most disliked restaurant**. If it is most linked, then it can be used to solve the problem of **Cold Start**.
#
# - **Cold Start Problem**: When Yelp has a new user and he has not given ratings to any of the restaurants on Yelp.For such users, most liked restaurant can be recommended. Or asking their details & recommending them restaurants based on Content Based Recommendation System can be executed.

# %%
# Plotting distributions of ratings for 844 interactions with given business_id
plt.figure(figsize = (7, 7))

data[data['business_id'] == "hW0Ne_HTHEAgGF1rAdmR-g"]['stars'].value_counts().plot(kind = 'bar')
plt.xlabel('Rating')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# **Observations:**
# - It is seen that **this restaurant is not liked by many of the users**, as the count of ratings 3 and 4 is higher than the count of other ratings.
# - There can be restaurants with very high interactions but the count of ratings **1 and 2** may be much higher than **4 or 5** which would imply that the restaurant is disliked by the majority of the users.

# %% [markdown]
# #### **Which user visited the most to any restaurant in the dataset?**

# %%
data['user_id'].value_counts()
# Out:
# fczQCSmaWF78toLEmb0Zsw    588
# 90a6z--_CUrl84aCzZyPsg    506
# 0CMz8YaO3f8xu4KqQgKb9Q    473
# 4ozupHULqGyO42s3zNUzOQ    442
# joIzw_aUiNvBTuGoytrH7g    392
#                          ...
# Oh9OOyDSGf4eNWGiNazh8g      1
# Np9IEqnLmhRB2T5jumPTGw      1
# g0-ejhzvo0ELNp04cUKWDg      1
# M0lyA1jF0zrXZr5TXlioTQ      1
# dDNfSFT0VApxPmURclX6_g      1
# Name: user_id, Length: 45981, dtype: int64

# %% [markdown]
# **Observations:**
# - The user with **user_id fczQCSmaWF78toLEmb0Zsw** has interacted with the most number of restaurants, i.e., **588** times.
# - But still, there is a possibility of **11,537-588 =  10,949** more interactions as we have **11,537 unique restaurants** in our dataset. For those **10,949** remaining restaurants, a recommendation system can be built to predict which restaurants are most likely to be reviewed by this user.

# %% [markdown]
# #### Logical Assumptions depending on business case
# As this dataset is very large and has 2,29,907 observations, it is not computationally difficult to build a model using this. Moreover, many users have only rated a few restaurants and also some restaurants are rated by very less users. Hence here I'm reducing the dataset by considering certain Logical assumptions.
#
# Here, I'll be taking users who have given at least 100 ratings, as we prefer to have some number of ratings of a restaurant.

# %%
# Get the column containing the users
users = data.user_id
ratings_count = dict()

for user in users:
    # If we already have the user, add 1 to their rating count
    if user in ratings_count:
        ratings_count[user] += 1
    # Otherwise, set their rating count to 1
    else:
        ratings_count[user] = 1

# %%
ratings_count
# Out:
# {'rLtl8ZkDX5vH5nAx9C3q5Q': 247,
#  '0a2KyEL0d3Yb1V6aivbIuQ': 1,
#  '0hT2KtfLiobPvh6cDC8JQg': 2,
#  'uZetl9T0NcROGOyFfughhg': 17,
#  'vYmM4KTsC8ZfQBg-j5MWkw': 14,
#  'sqYN3lNgvPbPCTRsMFu27g': 9,
#  'wFweIWhv2fREZV_dYkz_1g': 130,
#  '1ieuYcKS7zeAv_U15AB13A': 2,
#  'Vh_DlizgGhSqQh4qfZ2h6A': 1,
#  'sUNkXg8-KFtCMQDV6zRzQg': 4,
#  '-OMlS6yWkYjVldNhC31wYg': 70,
#  'C1rHp3dmepNea7XiouwB6Q': 37,
#  'UPtysDF6cUDUxq2KY-6Dcg': 94,
#  'Xm8HXE1JHqscXe5BKf0GFQ': 153,
#  'JOG-4G4e8ae3lx_szHtR8g': 3,
#  'ylWOj2y7TV2e3yYeWhu2QA': 24,
#  'SBbftLzfYYKItOMFwOTIJg': 83,
#  'u1KWcbPMvXFEEYkZZ0Yktg': 15,
#  'UsULgP4bKA8RMzs8dQzcsA': 181,
#  'nDBly08j5URmrHQ2JCbyiw': 133,
#  'C6IOtaaYdLIT5fWd7ZYIuA': 263,
#  'YN3ZLOdg8kpnfbVcIhuEZA': 22,
#  '6lg55RIP23VhjYEBXJ8Njw': 1,
#  'zRlQEDYd_HKp0VS3hnAffA': 1,
#  '13xj6FSvYO0rZVRv5XZp4w': 22,
#  'fpItLlgimq0nRltWOkuJJw': 3,
#  'RRTraCQw77EU4yZh0BBTag': 38,
#  'EP3cGJvYiuOwumerwADplg': 198,
#  'kpbhy1zPewGDmdNfNqQp-g': 41,
#  'bCKjygWJZOQHCOzootbvow': 2,
#  '8AMn6644NmBf96xGO3w6OA': 4,
#  'HLbhD2OyiMCUDRR4c1iXaw': 2,
#  '3iuZFgxUFKLxOplkDrFmyg': 8,
#  '1guJDgUfTiDdbgKqBhsZFQ': 7,
#  'iwUN95LIaEr75TZE_JC6bg': 143,
#  'iFa0SLpNeLbx6aux65mNbQ': 7,
#  '370JyOQfFcPSB9_jk641gA': 9,
#  'Ja8SAyDdf1aY-E7vVixJiw': 16,
#  'N3L6SDymSRkYQtTiSDmXSg': 67,
#  'F0dO68TECqEJBhBJ4P0qVA': 24,
#  'W_QXYA7A0IhMrvbckz7eVg': 254,
#  'PiDqfET_ZrDKJSLKe03O9A': 1,
#  'wv5-4IPtpVA8wdqXu-Onpw': 2,
#  '7cR92zkDv4W3kqzii6axvg': 111,
#  '66PQJEHC0tCWGMI4V9KT-Q': 10,
#  'IUWjTmXc3wLVaMHz33inaA': 34,
#  '1MyXsAhZK35A6EAr4reLCA': 11,
#  'r-t7IiTSD0QZdt8lOUCqeQ': 82,
#  'J3I2NClEbD1Xr8lOdjxlqQ': 89,
#  'jdoGEEy5s-5L1O_lNzEi2g': 28,
#  'aqqbh1NZoFk48kp0eqSLdg': 4,
#  'ynGxw3zZqAjahVou563zXQ': 13,
#  'Mb0psF4WQF7gZSuZafVr-g': 124,
#  'yy1SbjeyWiAhWfSr5d0new': 1,
#  '40aklZ2SQPKnlTPZdvAqww': 4,
#  'UL9chyH0a4Pj8J_9M6WSpA': 62,
#  'xw77viWz_BbmyntxoBVH4A': 2,
#  'uA18GuF_ezOH6tXkrrykbw': 22,
#  'U3uT-Phb8iL2iuZpAROZlg': 9,
#  'wJzMpk54FF2jeENqMBJ24Q': 18,
#  'EPROVap0M19Y6_4uf3eCmQ': 9,
#  'gTCM7qlVrwdml-hFB6aJqQ': 56,
#  'nM3vfxr6fcnN_nXdzwbVCw': 196,
#  'MjLAe48XNfYlTeFYca5gMw': 3,
#  'rWN1pg3mCF2btJWtG6JmJA': 1,
#  '0jJhjgr3wPin-8vYnPab6A': 1,
#  '-yg_AMAU2HNh48zcuQ13mw': 1,
#  'UHyDQ-laihWMGa8MtIToOg': 9,
#  'xP3o3-r0KRUnZqBSdIGJjw': 3,
#  'XqMkm-DD9VsdcKx2YVGhSA': 236,
#  '5je-Jg8tq5BWxJtDBmTK2Q': 10,
#  'IE_nJq65Qpso5fN4tG9zjQ': 41,
#  't8vH6ubd-6i9DTisZaQdgg': 7,
#  'iwWBF3nKoRMoy1sbkLJwvg': 84,
#  'BUeMRVgAQvBWnnrI2xcA1Q': 2,
#  'GVH_iuoPc0aP3ZNYlWuKag': 19,
#  'aLTl_OkLo0BFRxdz1n6sYA': 41,
#  'O3huqF3nBeWP9Zd6NmCAaQ': 22,
#  '68exKLCQnnZrvXNFOcIUnA': 1,
#  'YBVdmm5zlpLpi2_DiKsd2A': 11,
#  'gcyEUr4DXcbjnGRAWFtfAQ': 139,
#  'mfvezpz6ohS0NQk3DZdvqQ': 153,
#  'qLCpuCWCyPb4G2vN-WZz-Q': 62,
#  'HY9qpAamqLXFoa7xMwNntg': 109,
#  'P-9g9-6OriX0ElKpZknUKA': 17,
#  'qT17WVkJi0RvQ4nNPN6NDw': 67,
#  'Y9LxzNvQxKwLhy2Zo7R_4w': 1,
#  'ZoBrIw-7VgCOO30GJVCoOA': 7,
#  'ASi6ZgbbwXIwU2H24uANmQ': 2,
#  '8tbXmjYGsYFZXk6ppuwRWQ': 2,
#  'cwm_3br1CTH8IO8ZwWzFLg': 2,
#  '7izaZThzAWk2UjrDTL849w': 31,
#  'H4ewd_HH1DE0Y8RbC_7HbA': 9,
#  'ziCKT5n58tcVfgksImx0VQ': 32,
#  'Gi_ZP3Pjdvc9-a8aS3SH0A': 4,
#  '0NckJhx0qXykvvhsm-p7MA': 56,
#  'thlVIc8s6ZCP37UGMf3yDA': 27,
#  'QAwWrE6LLbVHNtZOoDdRRw': 9,
#  'v10WwWFKPAK6aKjghrLj3g': 1,
#  'bZFRqP7s0Vszxeu8_IwYow': 49,
#  'FpCmGLWHe5Y-kDS7ZYaF5w': 6,
#  '_w_hrcZ-9uObIBepDmLJwg': 1,
#  'UfMHoQ4lic1aCkXFa4TxlA': 6,
#  'kWIyajQP2mEv93yj34oemg': 2,
#  'P_LzcrlVXFdgBq_24UnlUw': 86,
#  'a_V8LRfMxGvpGtTwR2olrg': 7,
#  '8-2W5CmkDl9vrkxRpkiPRg': 59,
#  'uQYOGKahTkpR9wEVjaAOCw': 1,
#  'QKW7sYPWPSsIcWqSiDzChQ': 33,
#  'JnRT9i2d71pY8D8ngzCz9Q': 47,
#  'xOLR24JjRq3nE6lW-869Ug': 5,
#  'PFaAf7rqKfWXIPiG1qxCiw': 5,
#  'DowPyTFtqen32BuOmzuBXg': 5,
#  'rz5kClFIidz_-sfJm4V7MA': 1,
#  'P4XRTKPDREmWvPIg81CzUQ': 10,
#  'jKeaOrPyJ-dI9SNeVqrbww': 83,
#  'w70p852jPyabsc2JEIis4w': 1,
#  'cCwj4RJSKU4-o9ZZ1VTtmA': 13,
#  'ENJpS6i-s9hWiQg9ZGwevQ': 21,
#  '4B6aJJTELjivUXrL_LTlqQ': 3,
#  'E8Gh1Mv8Jtb6eJQjNmIPXg': 1,
#  'QSYnt4piL87oEWJHJ8_pGA': 6,
#  '-Wa5j14Rhps3DC2SMaaatQ': 91,
#  'rVlgz-MGYRPa8UzTYO0RGQ': 6,
#  '4xaC4c660LOb2qdVeSZfqg': 15,
#  '1wMGLaMIH7CcmJ2htS1rmw': 65,
#  'dCrd49_lbC3YAgTOZZwYmg': 1,
#  '_PzSNcfrCjeBxSLXRoMmgQ': 333,
#  'psBJOZfXxUPHmF8mi8G0pw': 24,
#  '_tBu-2i9uT6LFxh-TyEOHA': 6,
#  'VKiWDL608wBRQtk05ts59g': 31,
#  'XYVfcuxJ4x805zIWvJ17MA': 9,
#  'LZxnr-c-VsG0N4Ef-9iAyg': 8,
#  'efZh8TKpCz5AJTcuAnBxRA': 1,
#  'WgdgOlb-OIwKxb1p4xWwRA': 14,
#  'mlBC3pN9GXlUUfQi1qBBZA': 111,
#  'b60JsTGYbVqUGYbI81aOsw': 39,
#  'YPk47NcyWSkk-541OxyzMQ': 67,
#  'dQO0tQISZyb9L4d5ASnXyQ': 126,
#  'UHxBIipD-7xb60CGB8rOuQ': 3,
#  'gYIHSsoa260H544x9guLOg': 7,
#  'nH0YyEYTE7RMeAbeERrSQA': 7,
#  'pRw80rCPUTcBo2Zv5De1yQ': 1,
#  'vhxFLqRok6r-D_aQz0s-JQ': 205,
#  'W7zmm1uzlyUkEqpSG7PlBw': 94,
#  'bkRfY8jHdFxf7k8vLX4buA': 73,
#  'kxfUWPT6PuwieZHonfXtLw': 2,
#  '7a_7iT6nDMQc76bz3-TQwg': 2,
#  '6OWHDbEq23f24Vki_veHBA': 142,
#  'Mex8qXT7nR89uTKX_qtgSA': 56,
#  '0ouMuScWJ3GuNtWEmmsziw': 71,
#  'ETIAM78kYT_xPM8b2iqi7g': 36,
#  'SlCfUUr1Pa7CzzSxbMH1pw': 28,
#  'dxPBchN0OnHTENctEUm7NQ': 5,
#  'OPStKHloEOVxcBtFgkzh2A': 60,
#  'nZ9XFVETN4hxdK4qPb-T3Q': 27,
#  '3sJ62Mkavx69FBec71agYg': 7,
#  'VBEbhE0ISjg6xowGNiGmgQ': 38,
#  '33T-R7e8y7st0PA2HRyHnw': 4,
#  '1uTS7hrpgphH7ZDK8EThzw': 5,
#  'QdypppSRw2H5UtMu1IebLw': 43,
#  'px6RIT_CcE2Z1Jd52C8TQQ': 16,
#  'QnMPMD8Nh3ErZGfMRGAeYg': 41,
#  '8q2pilNlC3_mTfyDzp0TiA': 2,
#  'zFfXgANzhIcD-JkdBygcZQ': 14,
#  'vpb5jICQEl6vT0NlHq1dug': 6,
#  'hLi9rdbx4cXBklc4osQEJA': 3,
#  'UhryFhGe1tqdbBzAhdooTQ': 3,
#  'bkPFUCENKOYFDit-eV2PSw': 47,
#  'sEWeeq41k4ohBz4jS_iGRw': 142,
#  'CP-IE-zyc2Mv3jlaceElVQ': 156,
#  'XqU1PB0XWjcr3sUyZZGaWQ': 56,
#  'I5AcIAujn4X0fzjq-CTLBg': 3,
#  'i0A-c2yoHySmFhRV2sDR1g': 67,
#  'X5GbNXY_nNoa_vTZDD0aCA': 183,
#  'woXhdtL9ds78_mz8mOY4Vg': 13,
#  '0CMz8YaO3f8xu4KqQgKb9Q': 473,
#  'MZaI_6ffmE_XzjKnM62oFw': 1,
#  '17PPxx8RxjOUD_nQZ1aHEw': 214,
#  'RCmBxcE6ld-ANzEAS6yeUA': 1,
#  'lAngRi4lwBIHmjCBVLd-8Q': 31,
#  'df0YRtus3XaN64pzs8iteg': 6,
#  'uzWTAgkONAZd5NrfP9XXlQ': 12,
#  '-V3CXSxnUzjkLVqi1xGrkA': 12,
#  'BtQVxFotHFK3T2FtIrBWmg': 17,
#  'dYtkphUrU7S2_bjif6k2uA': 11,
#  'k99cC9QpbUXlGRWwxEe93w': 13,
#  'Ut8dgpxKahmC_9v5PbYOmw': 12,
#  'LH9q3LtJRVstt8Of4N1M1g': 1,
#  'TVJP9jSapI_jVHJ89mmijA': 34,
#  'e3LzMIrC6FtN9QeTvWiGag': 2,
#  'GeGDZ02UfARKBRl7LqKZuA': 39,
#  'qklF6QU-bi4Y4Bt4g6Sv8A': 4,
#  '7brf9WC0Gr_7bUBXEHs9FA': 98,
#  '5RVUt3bCDSA7F_SahuwZ8w': 5,
#  'Pk5T0OFCbl8mIKkKYyglWQ': 87,
#  'uqK3yvpg5Evk_XgzMW-lAw': 73,
#  'gsMVXAI9su3B26Fd4vyyRQ': 3,
#  '64YY0h0ZAR2nbzxbx0IwJg': 173,
#  'KucBnMrhalzxnD9AWrxwYQ': 105,
#  'VeJi5LINIEkV78ug-WCV0g': 1,
#  'HGeXdydcZ9nDn9fT87z4fA': 10,
#  'bMeRjJSiSZq1Izjvj7bvaQ': 2,
#  'vOw4NYgKe57qcJ5fOjk6PQ': 4,
#  'o7sNqbEsMrztrVV_3RU4Hw': 20,
#  '0bNXP9quoJEgyVZu9ipGgQ': 376,
#  '7kRN8IkOWlLblEltNlnfRQ': 14,
#  'DJIwm4UCnM-SOxXbARjPsQ': 45,
#  'fnO1oH3N5QMG-PvHA4F-VA': 8,
#  'ITBs8txD0Zu-YuxXCGqokA': 15,
#  'wxapwb1gulmqGVCNxVWjBQ': 13,
#  'bUy80XymVAeKV9_QR0y8ug': 15,
#  '2ARM6NFVciTzV21r7p8jiw': 42,
#  'jy1qPe0Tz3ewHacAtshmBw': 46,
#  'oC0kwGvgaAeT3ZIxdxTcJA': 108,
#  'Mva8f3RBztfxUQoUi47SnQ': 78,
#  '8KBmUXP4gUoGPxNKnHLpjw': 12,
#  'VyzwBKnq-LJ8OjvG0ZTwrg': 12,
#  'fSL20coJsOi_69A3u2OKcA': 1,
#  'GubdNFoDAsiwE6bWIr97cQ': 126,
#  'Yk37VAp452K7FwHWd1rrQw': 118,
#  'JnJDO8c37PnwsP0P7-1v0w': 1,
#  'JgDkCER12uiv4lbpmkZ9VA': 294,
#  'syF-6VzPdjmCXbTye6N9Eg': 9,
#  'EO5Q9yRT7LP00iQYpSNuhw': 1,
#  'jHwEOGkgl0yQ-oLWxiCAGg': 6,
#  'Rv3k5uOZT5i40aLmlhw4DA': 1,
#  'okcNd96gHHf_83wly93bpQ': 4,
#  'TKiucSBuj9twVDW-BoAdrg': 2,
#  'nsjM5lu-8CL97d58pJuVng': 5,
#  'K0euQLFAcKhQPZ6JxGAryg': 116,
#  'MxeHhDzPsO9P8swTby_faA': 8,
#  'UfGlNf7MbKeRPp4ASUVTcg': 1,
#  'IldNKx5L8unlcv3LBSs-_g': 53,
#  'MfbH-4cBh0EXWd7IKEuEhg': 11,
#  'T7J9ae0wTskrI_Bgwp-4cA': 248,
#  'qQb4pg5uqvjMOfGPWbIkeQ': 57,
#  'lmiDCrmas8TxRsbIGZX9Pg': 94,
#  '3w-JiPus8k-BR5PQ7egDvQ': 43,
#  'nK74XYEJBa2Z5OLN5O6HYA': 1,
#  'qK_o6Chm8VakPzeMCurtWA': 2,
#  'mQba83gB018LlGt51r80ZQ': 75,
#  'hDlSSyDreM9xY4yQWPm54w': 96,
#  'tVoCVBUg-ubBMLQlX5_SVQ': 17,
#  'PzeWNJ_hrhDzs8NdcBA06A': 1,
#  'vE3yvKUayE1WxQPuRB4eEw': 1,
#  'gW-ukHucTfVCnFCKKxPJzw': 30,
#  'N-D-d1Z4UybdlkK1HxlNPA': 148,
#  '23iaSkV0K36OetsHnXLoYQ': 1,
#  'EIQ8gPTx5L-zXPlYDwWGeg': 5,
#  'LKJswnMTubEGjJXFDseHKA': 9,
#  'DA_SU_MbfgfalzbktcsBzw': 2,
#  'z5QQGDqErjMKD8XtM00s7g': 18,
#  'FIin1o5cJb8thgJuP8eLCA': 7,
#  'JniV2vR1TZFBCrdTlIOlNQ': 34,
#  'ca2Sa9Enqg2GlWFQ95p8bw': 91,
#  '6VGodLwjrYPQYq0qxfRyXw': 7,
#  'gdLc6dq1NpjHj47WBUNZ_A': 11,
#  '4o7r-QSYhOkxpxRMqpXcCg': 3,
#  '8qe2c5uRlAkvNFvDriBm1Q': 29,
#  '_OLBq0aZR7K-UdPCrByatg': 6,
#  '9UxkYlsD0cnziYN--O8xug': 5,
#  'KSTOdz0lSFCkqBSRNwjERA': 109,
#  'RxfFQxUtSIGYwTKU_rvAeg': 146,
#  'u51Y4YnhAbWn0nghijc2dw': 8,
#  'Zgp9T6IOVFOozrWDw_mUGQ': 34,
#  'ND95DgvN7ba8MabfXE3lsw': 58,
#  'nbofxFWHORebBHh10OgYLA': 86,
#  '9VmTOyq01oIUk5zuxOj1GA': 24,
#  '8-mw_aotUGmP0k0s6QKwOA': 48,
#  'F8C1lM853UmUed3jb7j-_g': 7,
#  'vKs0r5yZhfJYdBSd0J1a3Q': 1,
#  '8WQubmP7G0NM3IyzyMnCEA': 124,
#  '80PHOfM8KOBb7xEQN4C0lg': 17,
#  'tePGwo_ZH1Hu9bkCNhMJmw': 7,
#  'OpUXG69nP4YjlEZDlkdVcQ': 25,
#  'QiLOh5KHp81eiju-n-z1Ng': 10,
#  'DjMYfLoL9KsTIcvOMxwkhg': 15,
#  'usQTOj7LQ9v0Fl98gRa3Iw': 245,
#  'upssaszVG_egJVRKBU5Dzg': 49,
#  'wdtoa9VgowEdiYudN8T1YQ': 1,
#  'h7v_M_0-YVpSVZ2WD7FpAA': 136,
#  'scxmg3Pu_jjpXSyFWH8-Cg': 28,
#  'UE1UIi95jSk5tAzOdtnjIA': 38,
#  'd0nD0TzD_NvzQLHE6zL-1g': 1,
#  'wC1CPV5bf--bDLtlhNSPLg': 130,
#  'Kqvfep2mxS10S50FbVDi4Q': 241,
#  'zsBmBMbZhPuWKueEyKoI1Q': 10,
#  '6XDBxbqC3kD5xvQMCkwhNQ': 1,
#  '44FZYP4fQbeAimA818oHtw': 2,
#  'RIAkOx7jS_IYdF0ZO0Hc_Q': 10,
#  'qABKRj1ggJmtvrL9FMFtuA': 126,
#  'onCVo3jNuKsSk8HcpDE1sQ': 36,
#  '4-BhPJwJp6d-XMmo-w1FRw': 6,
#  'SGXahHRReksq3m_Zk9V20w': 155,
#  'Ps1Db9zOatoF_76FZNO5CQ': 193,
#  'yov4PgFnEIOimzKdU2wV0g': 2,
#  '3gIfcQq5KxAegwCPXc83cQ': 340,
#  'ZdDmxmGVhHHI4PzmVdTzxQ': 11,
#  '_jjIaczpcVDpHlH6l334rQ': 80,
#  'P0Ki-xij91UU-_Hk4t6tGA': 1,
#  's8fJCSltyub39Q1dqzjb6g': 87,
#  '1ADvDGbYb3DVakds4jCAnw': 24,
#  'ky9pQ8AKufvZ63IxR41jGg': 151,
#  '6kmu0mYbdpMIOZ6Y0eVsxg': 211,
#  'Kq4cVcc_g8amBkHe5dJ01A': 6,
#  'Lmgv46LyI1PlLs0KNIfYFQ': 6,
#  'GPPHDWEZGjiw777_iTOJ1w': 74,
#  'eA7hkwrrknhxhqs-dOhDYg': 30,
#  'KpC10_UEJuga43WadHCmYw': 76,
#  '-Dc9up-WyQ6XrYTjmL3GaQ': 12,
#  'UrjEdSRi5vry3bQ1NKyLuQ': 2,
#  '_7el1cOgnfkNfmZKi277bQ': 82,
#  'FHDI8M5sm6lrZXNUBZAOfA': 70,
#  'ZOKN67ZtI1ClbRmcAR4yKQ': 6,
#  '5lq4LkrviYgQ4LJNsBYHcA': 136,
#  'kiL8inOENuxBRJjknd7aNw': 10,
#  '1ylYrKcGNA8MDkhNBTjHMA': 79,
#  'msgAEWFbD4df0EvyOR3TnQ': 7,
#  '1r7dSiDim_U0GFn8V4HvAQ': 1,
#  '8B5pqCDFglMvfW7qj5W8TQ': 43,
#  'oMDSmhe72hjxoR3EAj6sXQ': 25,
#  'K46kUag6aS0Vd4JjiaqNsQ': 15,
#  'kvL7bId7FbaMi19TFl3h9w': 37,
#  'Z6_d6w5G5QkosYMRhct_Vw': 5,
#  'TvDqY4iUY8kNGqyvKpQfVw': 5,
#  'JffajLV-Dnn-eGYgdXDxFg': 371,
#  'El1Q48x6ZfofQmaBZTrduQ': 2,
#  'iBW6n_0yzFDn4C6_0sf62w': 1,
#  '7yqlOyMgwkBgq0O88a20FA': 1,
#  '4ozupHULqGyO42s3zNUzOQ': 442,
#  '_4lqpCYCqOQzbB6xQGGhrQ': 135,
#  'oeN1mnXSqa_Mt0L_-bp8vg': 1,
#  'J72XoQspNBmPsX2iKl2YvA': 71,
#  'LL2Kk0jjD9McDPfPEDbZBQ': 14,
#  'wy9AIj-FTQaH7OAGg3xBfg': 4,
#  'IYJg3a-NTaymcYPOfRrcsg': 4,
#  'wIi2J1UGRB2G_3vu5eNK3g': 46,
#  'HBRvlxpo1PUQS9uU8csDTQ': 5,
#  'Rg4gzsz3w00vRlIOXcGUIA': 55,
#  'I0pyeAcqXQl7Rv-DQmgHow': 12,
#  'OqisxqKDGaZwEvLm1OG4dg': 5,
#  'Ypz7hxOCnrg8Y8vxHJU-sQ': 87,
#  'WmldRvl1nKxuKM6weiO6fQ': 25,
#  'nWouNfZD3Pw08RYizxkqcA': 111,
#  'dGfOZWZbYaoTlFiW8EnAFw': 2,
#  'fR6Vch-D0L6OBnLMl8f9Sg': 20,
#  '3UHFF9kWZgIFHaaoBk5xCg': 2,
#  'YgucNL2tibnjEmDLqHPqow': 16,
#  'mAWDlmTrBCbxZftZfdJf3w': 14,
#  'E5QyEU6FCQwnTys0S73zNw': 135,
#  'kGgAARL2UmvCcTRfiscjug': 191,
#  'chI2p-ROg2tXI2-tT2_G2A': 99,
#  'y96CV_ML3MGld3asJxzusw': 13,
#  'hJBOxmNREXmMGTfXgMcGug': 31,
#  'Xffah_1oR1AYdi3TiW9Ckw': 3,
#  'D6J7pwjvAsd9VwzIrMzC7w': 4,
#  'OfIm-r7GAv7p5JwzPUYDXg': 4,
#  'aB_1_t8nAUHkS2nAFxcW0A': 2,
#  'ZW8jy6ehrNzn9A5iCubVGg': 53,
#  'gh2OwESXrgVyufGz_NPHxw': 10,
#  'oaz8Fhe38u2DbeTguvLkPA': 4,
#  '-YLtOLwOh1_xxxBnGtuvNg': 27,
#  'Jrx1fLr5JdqgHdIfMT7wag': 32,
#  'meBgdnN_Jw9MOwz3ZzqQEA': 27,
#  '1rE51uSipcbiqQlkvj4Kvg': 7,
#  'lPaYMDmJbAnv_3pmZH_inw': 320,
#  'yneTxW_9TTRXTOgJDH9fnQ': 15,
#  'pU2lBD_W3VNvpzKZsRzi2A': 42,
#  'MWt24-6bfv_OHLKhwMQ0Tw': 214,
#  'UCQNrwN4_hHHTWYa8cqe_Q': 117,
#  '7Pyi-M7MfO3R2PHTuVY0TA': 12,
#  'KLekdmo4FdNnP0huUhzZNw': 109,
#  'KxmOlAI4f4bwFMDPzRRzNA': 2,
#  '3PleJJEDyGLIWqaW7JlTyQ': 14,
#  'KICFDhBX25ruK_iW6gLgTA': 37,
#  'pmkI2GIZ9Qh9LlHjey-w5A': 1,
#  '-US_SpFlEAsu3ZRWY8Bsvw': 12,
#  'DY-U7c0451pUs25p_AhUgQ': 16,
#  'uHQ2ZRacs1Zhi_38MQz2BQ': 4,
#  'EcgpGtxB5916NPqvXwMcjQ': 96,
#  'kAMGHCEOlJxlY0wtxao9Rw': 1,
#  'oCFQmDotqcyIYAY1JyKUPg': 28,
#  'AK2Nt1PdjHlLVoEzF0FqpA': 1,
#  'z4Z-wIgEcnOjeHclfF0yXA': 5,
#  'T5mD6ggC7fh48QgXR0LevA': 198,
#  'qZrArI2ohkYkQlELl13BKQ': 129,
#  'cZgbUqTxXV0-EIzRZEKlQg': 3,
#  '9pW26TfIHW2GV1zxCfvT-g': 1,
#  'BRpbP8FI9Q-MULAj6iyXHA': 9,
#  'HnqzojvN3AyZHjslUlxiJQ': 8,
#  'IXuKjVb0F7t7T-BTpwLqKQ': 8,
#  'kG8jkVFgOAOq6Ht6RvAjEQ': 108,
#  'pIm17SVRo8IdhGoBD4qbnA': 119,
#  'W9ZG5q-QIblXYeHgaPS5Uw': 64,
#  'YbHL_lmvARxf0rz0WlVQPQ': 32,
#  'b6CyeouS97Y8YSTi8T2xRg': 10,
#  'R7XtOWCTIh-VzdVDu9iYmA': 2,
#  'hTKFGpi3ltCV4B-XDFRT-A': 17,
#  'n9Zg0jlOGtxfIrvoPm6Hhw': 113,
#  'DsoD6Nyv4n4gQpjIq_y5DA': 5,
#  'Ksu2OeDaXiHurIX8gUHmkQ': 24,
#  'gg_OKjOAl_vVmdh5ZETuiw': 71,
#  'Xo4i9b1ytYPa2hbNXP_mYQ': 7,
#  'g2mozOU_F1nzpjLDY4CfzQ': 22,
#  'DYDCOM77BTeQo18Z5tYlag': 3,
#  'x5ve4LVa-iIfZ65Qe9Pqvg': 10,
#  '7GC9fVWKa4a1ZmBGLH6Uww': 232,
#  'zNR8Q6Fw9UvlVSgxwEy-3Q': 7,
#  'GveOUdXagY6tuZttk2SUew': 7,
#  'AV4-6n6SKop4Bp5S15c98Q': 9,
#  'cVR4YQYdouuuSTra25akww': 2,
#  'du6KeE54IFbPiXpU3LOd1g': 194,
#  'hqnySkbeUJGoC6h76gtSIQ': 35,
#  'SINn9supzIkv77lgB4OnZA': 11,
#  'Y_iCmH_z_T5cOy3_8p_pQw': 1,
#  'yDCjypQo1dpQ7rwgNx9f6Q': 7,
#  'oTB3jV0wp1pf3bHy6Lxv2A': 2,
#  'l53FUDHRHLg7BQ89KgAtxQ': 254,
#  '-vRFUY8ixuNniCCNVvmkRQ': 37,
#  'JlMLNh0ECg0tgZKUL818DA': 1,
#  'c3yJNjz_K--z4CIpR7yhvQ': 139,
#  'y0kjuHVdGQhLd-bqQ0gZnA': 42,
#  '0mqHhdKEdak_A1FBhFNXqA': 315,
#  'Y_ZITL9cYCKgBgDCwUQrow': 11,
#  'WeFxOADIRIDgdgjg8PmQdw': 5,
#  '_Lz4b5QL0K8ndeyz2vxslA': 25,
#  'qo7OFaG6cY3nHyzVHaRskw': 2,
#  'WRY-wk7t2u7xxrIwWbQu0w': 17,
#  'DKi8rNg_jTZpVYs5BVVnRw': 2,
#  'HJLwvRnK22elM2vA4C4XtQ': 68,
#  'LX3cTVaS8f2UF0Uuafsfug': 160,
#  '45Cf2MLgLhwnXoLY_zY2EQ': 2,
#  'MppkYbypgGl7h4pCWWM3rg': 2,
#  'htC49ZwXiKNka5cp0GKBfQ': 247,
#  'Hb49IsEZltm85wLz3uMrmw': 42,
#  'T2YhY--VPurB8rPJ-Q5giw': 1,
#  'DrWLhrK8WMZf7Jb-Oqc7ww': 88,
#  'YavFbDG7DUOTXJBLxpq97A': 23,
#  'lhf22sqBafQv6CXu2fCmvg': 2,
#  'wb1kSEFZzyy5_UAbYJrEYg': 18,
#  'B4K5ruafil9RSDiTIL-1Bw': 93,
#  'mU5GwCA4uiD0-RH1qt3jrQ': 28,
#  '90a6z--_CUrl84aCzZyPsg': 506,
#  'eX_vXeJMKDp1oMZZ4FlI9A': 12,
#  'q0KigjVBtb6dfRjX3QJbsQ': 71,
#  'jvvzoDYVq3BD_Dy7eMRdhA': 1,
#  'DeYRUi2YEFYZLZ1ukOGd6w': 11,
#  'fev0iI-XDrteD4SYRKjiUw': 211,
#  'pq4HdRAn2MFArQCFYXkYkA': 3,
#  'VcN9i7sPrGSOn4BnpOJ9tQ': 56,
#  'eZQ2b5dJDlIji9AtfdOE0g': 12,
#  'uzEls2fkJZPUH050rON2pw': 3,
#  'hFtlFksrcLaWHGPNa6SmeA': 174,
#  'oERfYLY8vainWu5m1ZQS2w': 5,
#  '0wNFzxEof0RDrWPLjDlwZg': 22,
#  'r5uiIxwJ-I-oHBkNY2Ha3Q': 5,
#  'kgfAnunPn0sI3Ycp8EypyQ': 2,
#  'yA77gvXdxFViK0mZcSiveA': 9,
#  'rgrECAY_EZ_xFdSx6CGfvQ': 12,
#  '7k5mTaDV609kLd8QFqYznw': 2,
#  'LiNbZqDdHLqueYz4nORWzg': 14,
#  'LMqKXdbwYdCqCCF64QbVkA': 34,
#  'zw-bIcZP4_VEi3UetomDeg': 4,
#  '_ei7Bs7tciprz4im-_0kxg': 9,
#  'yJ22u_1l01H4NM3wCowIKw': 36,
#  'qXxwTfCGF9tAvXOrY-hWlQ': 13,
#  'bFVetbys5Z74h1fcihmvOw': 31,
#  'R8Vm1249P4E-aZCuiEj7eQ': 13,
#  'gcuwbVN0LCBrOsp7VCTAvQ': 6,
#  'I-P1v7sRjDLEfVOndp01kA': 88,
#  'qg9Jn8GeqQ8EuxNUFDshCg': 7,
#  'MrQCy8eJD1x51U87J5C6ZQ': 24,
#  'AVCBC2G5RjJM8tu_PebFPw': 27,
#  'nyHh14Vb9S269-kGKaUelg': 15,
#  '0qIsBt4EzBDCKrIviV55Ew': 118,
#  '4QORbyhfN01oKR_GgBstfQ': 1,
#  'YuSjiBCf_3j1Oqs99Aue0A': 2,
#  'cMNHD4NWHvsKhmJlx5F3ag': 4,
#  'Ys0ZU50fVW-BeDGjKto0mw': 31,
#  '2OLdiDZNdrPkdjp1WmW0-w': 37,
#  'VqSCQCva71Q-ZVcMsYfQuw': 66,
#  '2rlBbFPHyZjXSFSE8r551w': 46,
#  'ED5xDqDU9JDtlVEOqNCB5g': 1,
#  'tLrjg5jMmBfnnTs3d61SWw': 16,
#  'vU1bHO3IjqLnf3_9Igeluw': 18,
#  'k8QnA7UNbe5DBCmYqxYs8Q': 2,
#  '0lxf4v5NuJ1U6Bk7SGAJ5w': 164,
#  'MOpFJnB5HyXdXW1sMwz7Bg': 22,
#  'ng3hl9D1EzsmSDHnXXfGBg': 8,
#  'pQ6ij6cOBRB3yJGHbVZHUQ': 57,
#  'CjL3FtpiDzhNXTQPw0-RBw': 40,
#  'Gy9nOzH_L8NGCjrQr-ntng': 23,
#  'cRyNICH0mhjxagvSyVr60Q': 85,
#  'UuwjD6MZf6Z6QlNphiXRjA': 147,
#  'mVPISwK-W6gmlbR5oemOsQ': 5,
#  'hw9irUmYqNe5zSW1V1ybbw': 1,
#  'f1-pIw_p0ifzu03TXjPRiw': 76,
#  'dKMzuhnwGh3hGxP0QH7m6Q': 33,
#  'c10-vMDNqbRVYcM4nrhfpw': 1,
#  '2FiNCj5rM3nF0qgaWf86Gg': 74,
#  'ZzaGa2nsW5bh71N3GOFO2w': 4,
#  'vuUddBhwlrVijAAFvK5UTg': 93,
#  'QUTW6GQnEAJSqrzoUJ0m7Q': 3,
#  '8QnZXXA_yJRd_eYWOzcYUQ': 6,
#  'I4GolEA9L0k2RfH4CauL0A': 2,
#  'LdxngKjcYJTbuf_Q4If3Gg': 1,
#  'dTTbYe3Kniw0KLpNUYinVA': 1,
#  'g-rWJxGx1EKqDORpkZXjJw': 5,
#  '8PSUiFWz11tGdYy9xEFPZA': 3,
#  'XK3jzcg2pibsHm6nlCn08w': 17,
#  'JkHm-xBNa8KKNvWH5TKk4Q': 10,
#  'A7p8fnVMFQ5GuMY2Szb81g': 10,
#  'FW5o1j_WytQAT6vGgs7tvg': 3,
#  '9Z05mtXrXJ-22PElwp1ahA': 62,
#  'P2kVk4cIWyK4e4h14RhK-Q': 244,
#  '55-K5KXdbrUGQCNF8z3hHQ': 18,
#  'KzFTp00JdzuggUHaRn_uzQ': 4,
#  'TwK4rCo5Q_OnEP3874xTLg': 1,
#  'tcWQQaDc0BH1dwhyl6ynaA': 4,
#  'WEuIqh8ygm-bH81s8lwD0g': 30,
#  'FFfBjFZWkjMnlZPwbufAkw': 2,
#  'k3yuawPEvzlAJPj_RMO0MQ': 36,
#  'Ske6pb78p1AeeBh0GulEJA': 1,
#  'PDFku3Ozng656CxAWH1kVQ': 1,
#  'fczQCSmaWF78toLEmb0Zsw': 588,
#  'sA0sK9l9VxsynxvrOgmBXQ': 3,
#  'edy9zILE5uaa0B6HXEekLw': 12,
#  '_2oYcAukTIaexAnsjUo9tg': 28,
#  'LMlBCXFVAHdPnSA94jc6PQ': 21,
#  'zzmRKNph-pBHDL2qwGv9Fw': 23,
#  'a89BrWkaBblvdBGdFy1YUg': 14,
#  'ScR4Kp6zM9QYpi7pEE3pVQ': 5,
#  'Vyl9tU5OeDcZND37iObmOw': 24,
#  '3Zi1udoY2iT9s8Q3X6tgZQ': 89,
#  'bcZd4ohK6CIT_BOQ0_O53w': 102,
#  'k5U-0FBwvWUob8dlT6RvmA': 32,
#  'TmC0qdyUgXCkKK47vwLRPQ': 10,
#  'Qm44BhvzVRN5ugsJWK_Svg': 7,
#  '8SFpYIJed0i6NMr_2rYJhg': 6,
#  'KuPscbI0KPxudSMPZIcrCA': 91,
#  'bc8w3CYs70_EgwTxQHVjQA': 1,
#  'bvYk98zUE61KoWifshskpw': 26,
#  'RknsoxpICgtuuv46uaTpyw': 87,
#  'd0wJVf7Gv7v1B-HHYhxZtQ': 101,
#  'p6Os13EIOkUOUK5pzd0-ag': 10,
#  'LiBeWMVMk4pI3hRrsYiAJQ': 6,
#  'hduuRwJpz8gukqbFC26rcA': 10,
#  'NHAIwjKa8RfSzlwATIsAHA': 2,
#  'xg4AdOGHFxJyWByFbG8stA': 71,
#  'Cp-PV8rsypbO-xBrQ6KmQg': 224,
#  'jdeNI5TTTuM6mj3HTgstRA': 112,
#  'r-zwGpl12La0MQn4Jf-2hw': 12,
#  'oHn52UJAeJQJxDOob4FEAw': 35,
#  '5RxpP2Woo7CpOGUmKgDyAw': 58,
#  'uQcl8Usm1cK9bQYbpXYdiQ': 4,
#  'NMNiUVcUFLPWjQme5Fo6Dg': 10,
#  'pcYFt1EjfOizhvRJDiz3AA': 1,
#  'IESg-R-NaG8yQwNdxxftyw': 1,
#  'ur1hCrzqzOLB0vCnjONTzA': 3,
#  'wB7YiVcqEWyL7arlVLsa-g': 5,
#  'ehCtzkedHa4Oq5c0IJ9X8A': 5,
#  '4OFp34tCTh9Pps5nsjt_lw': 12,
#  'BX9K5JMU-NnjxJaNKxImpQ': 43,
#  'a8gpBi7biN9VAoJwKgl3Xw': 39,
#  '8qSr4B1NJL99rlylewUjOw': 2,
#  'thdVzCfKx-DV0zYWqId3pw': 230,
#  'VaLglvhXegtW1OMF6_Xfag': 20,
#  'h3TnHCqFga0VgPO390PjKA': 53,
#  'Zwtx7FLZcK5F2P0-Tz8mHg': 127,
#  'g45j6zxyjTmEy6nhf42o0g': 5,
#  'JPdGiAA8qNS-9Re2RN5qVA': 4,
#  'eL2AbD_vXdP57eewFH21lQ': 38,
#  'mRAPMBM3dbw8KXNit1aDCw': 70,
#  'k7hlbzPqiyNRDSKDNsevRg': 2,
#  'RqfHaelhNMn-UpTRnAtw8w': 11,
#  'RgqU8dg9zaSSkwAlyB5Isw': 14,
#  'AKfF9LglCfrV6SKoIDgnOA': 3,
#  '0H9ne5frm1GjO6TjUwbxlw': 71,
#  'MBLcbQ_miC1c11cfXQRKoQ': 70,
#  'ZKuevUayT2eqkGNrJm2nAg': 36,
#  'q3Fa0PhTGzRl-05fXHIi4g': 46,
#  'PWtlBs3PCH1l0DdypgEszw': 8,
#  'My9DUYlhgwARA-6JJ8_Y6Q': 34,
#  'GF6IArfVHEFAQmwekt7wug': 7,
#  'EbnK9Tb1iE8Svz2z-QPxNw': 1,
#  '4E_nPWw89FLFHdNsEgMH-g': 193,
#  'qyy2X0sjuwcikplzdATfGg': 9,
#  'zS4hmZxiOa7gA5yndaC4EQ': 3,
#  'Br9mpMhkVunsp8Un5GpYWA': 63,
#  'NlZE2Oir3HLV0XdELgkjcg': 22,
#  'ZXTIFYJPsqBDeBaoGKJc_Q': 9,
#  'sALB8-F04S9VcZMF_GkGUA': 152,
#  'aTi0NVrcPJWbN6jAsJVcAw': 81,
#  'E-Bd5r6Z3zMGA75_D4IRKw': 25,
#  'kFhzv2iDyBrqvfMZHt-yYw': 1,
#  'ru6uX6w_ms7B_Q3U7wMYbQ': 8,
#  'Hy8FHZmJIRP-WNMjQZqeMw': 35,
#  'PimB4yUetjP2ylJGMpK21g': 10,
#  'n1h87EmG_HBlp33v3X_QuA': 14,
#  'PQOk3AaaODhSykbqYsSgEg': 7,
#  '6gt6iJB1hiFvSrms5RWxgA': 3,
#  'Ui00Ci0DO3TCElTJ1rVY6w': 3,
#  'pIuRwWH-mVwJeD1m8W2yng': 7,
#  'r8xfTpifZ7gP5Cd5CSQaIQ': 26,
#  'JeBi1WOHYnCW7Jmi3-nrWw': 4,
#  'mym5tXZoZCbuPCYQzI5Ysg': 102,
#  'C5N_L46b_EYU_0WQJt3iwA': 4,
#  'ykg3-2C-8Vv3K4mVj1iSfA': 19,
#  '0Sunr838_CEnkDRSAgaz3Q': 7,
#  'qQns9dP75RNOWOVWI_ZKZw': 84,
#  'nc3cqVN0UuB3m50-CcMftw': 149,
#  'OCsrk-5wLPhFMMGZUQasrA': 13,
#  'n1ZKHhVozfzCDLEgsZTrkQ': 1,
#  'dVJ_y1NGSA_g6rc-NDDWHQ': 55,
#  'L8NC1S3O0AgBwrysvG1wfw': 21,
#  '4jZwjy_SE1LOmYFN9IWibA': 4,
#  'aidmFfjOjpVKD-5L4J6X7w': 34,
#  '6K6GvIJZ_G_luOrVZDwrZw': 31,
#  'L3XWX_dd8_pYnRSMdppjDg': 65,
#  'IEFyvGVxFKhYJDyEV5Erog': 17,
#  '-yaUMGgbVm1iOG_j8CmBtA': 1,
#  'ebCOe-Bavz5fYCVL716KIA': 4,
#  'rR5W8Bj-IGu6sw1_1v4m7g': 74,
#  'VlpwSHJnXruY2nWJMcvg7A': 2,
#  'hcctCQy3bdZMezrUKkZLtA': 74,
#  'hpuc-b9xxcrOWluFYmCLoA': 1,
#  'vTvxsif_dlYJOtFxS-t2RQ': 17,
#  'IdcwNulMu2xQN8JDvm67SA': 12,
#  'PlYBocPQMxzbDWLGIGAa4g': 10,
#  'CuLj9-1BYbK7KkmO2dC7Aw': 3,
#  'Aj7Gx0gmjb-tX9tJ4IvqKQ': 1,
#  'XaSDZk_rE3D7WI4EKtXM2Q': 4,
#  'V4VW69mBsRzfa3mLmyBqLQ': 14,
#  'w_hcSjqLeSZQL9Rx1UP-Tw': 88,
#  'uNbB1uR4EBhmygUc3IfPAw': 136,
#  '8h5EXsiEuK5_igQ0cgxPZQ': 17,
#  'ysINNe8YpbOW_-5T5CSyhw': 20,
#  '8Uuzc8YpvQgGLeB0X-Ferw': 7,
#  'oKzkyfGalJC3-BOeLLCcIw': 29,
#  '04xW5mhSBaCzpjbcf2VSZg': 86,
#  'V1k7XMUX4qHVUi-3IUYzhA': 8,
#  'bGvtW70L5c2SBp6mwAvqLA': 2,
#  'aqmtZa9o9K4casagyyfpyA': 13,
#  'QiR2X306Yzd9fuJdKDhkGg': 37,
#  'wvsMlpa6U9RV4-_pU4gBJg': 11,
#  'DOJM58OkGSsIdk2qCUZnLQ': 85,
#  'VnOtsJ2514YIAd0fM2O8oQ': 16,
#  'VcIlVWhLQLlKoHfVhsA97w': 25,
#  'tueZZgG49lLPMj1gRkM2Ag': 5,
#  'KnutNOkfu5t1XA8rEhiq2Q': 5,
#  'gC9JZOzHYxJd8IxUlzoqtw': 1,
#  'DW15zMg6lrCiSGwo04uWkQ': 6,
#  'gOvKWYXobX_Pgzsz-K8auA': 2,
#  'OOxLwlNadygUwL_aG8KnSQ': 14,
#  'vsXP832M0kOxKpfduD7dWw': 210,
#  'JNfR68wvXOCt0Toy9OBfDg': 16,
#  'M-d7R2GVDqUi8iBaLyXcwg': 2,
#  '4aL1FgMljGIuDNksiLVKDw': 15,
#  'Jw3ocYlfPw3T7g0OknI-lQ': 26,
#  'x46c5z1ldZHuYcLlrIf1nA': 14,
#  'gst9ZZo44SwKzg9F1IHpSQ': 1,
#  'CC1INHcQo7eM-SST44UnVA': 8,
#  'xAVu2pZ6nIvkdHh8vGs84Q': 53,
#  'ZKz2htCNEjDUPqiImJhHrA': 5,
#  '9F3ZmyGKIA6ALNWgEq3Log': 30,
#  '0q87nf1yJFv0GML2J64Ttg': 16,
#  'w6Vv-kldGpmvSGqXvTbAdQ': 8,
#  '2qnz2y_Z1nDo2HqqfxJxSA': 35,
#  't79B56n8IeVrMNmM4QU2Ow': 4,
#  'J9u2d1P-nr937LGlZ3wmHQ': 6,
#  'XFLeKAsj3UKv5VPoIQjdIw': 6,
#  'dEMm29V7ktNHndxwXzhPfA': 4,
#  'f4_0MTexPnmvuWwjTsR_mQ': 6,
#  'oXBahXJCXUEATm5IVexw8A': 79,
#  'AdEy5KAIlMAy8xHyuMQCFg': 146,
#  'y9YW-BpDACEGytpX3NaeRw': 24,
#  '61CTpBsZmaYbBO0qOZzROA': 5,
#  'omuO9FVYAVRTybkSc4a4fw': 30,
#  'mqueHx5CFC9IsZxLQb3H9g': 11,
#  'ikm0UCahtK34LbLCEw4YTw': 328,
#  '4lkTIhTuMhLprQprGlTRlA': 95,
#  '7MN4_lEG5yVFTaEHSfJMVg': 1,
#  'ZcjSjT_7mQOx2LOhYq01bw': 18,
#  'lcu7u9kSWMeSNq6j135BfQ': 19,
#  'wEwU88bt18BUf7DhHDRbHw': 22,
#  'w225lKHnX3jorkSXWgss0Q': 1,
#  'kBM2vv1yEDqByi5FvucHYw': 8,
#  'V-gZC7GXA82mYfvWprtYJg': 4,
#  'cZWYisGrQIuN7Guez4KGjQ': 4,
#  'jt8jtEY1K6TD1FBzYa7HGw': 25,
#  'eapbAr6Zi5G8rK62gaWT9Q': 19,
#  'GnZWh25MyJD1d5FMKl3QmA': 88,
#  'fpWiDfJVWqDNWbfft22anQ': 34,
#  'gDl4dMYPpuuIaNAW_Bh3qQ': 8,
#  '9NyCrQI8gvY73gz7hSNY8g': 6,
#  '2CdbmUXg7kkmbJ1XSDrY-A': 3,
#  'Phj1jHdpcPPBE1hNg9-Tqw': 38,
#  '3XyuBpNbvrHukaEJyWBAsw': 32,
#  '2KNPtV5E44vAiEr5BvMkUA': 68,
#  'EabJsW5sDkfUx0WIhqlJeg': 13,
#  'W9h1ufjEzDp7THyAqRw65g': 133,
#  'yGs16xQiN3dLo03OQyto8A': 29,
#  'ytr46wNbedr8-iqSZngl8g': 17,
#  'DRw2GfcyTo8wjx2G27NxlQ': 1,
#  'oIVsVM8H273aoT1JUmsDIg': 102,
#  'OOYZNIBX1Qp7fUF7IVpXog': 1,
#  'g84VjttN28PWiv_WtdhnSQ': 102,
#  'aXPNzAxz2JWrjelJdjdfqQ': 2,
#  'U4E0mci8eBfGlwFLWo2cIA': 1,
#  'rY0T1Sx-kSeSHgnPbLOA1g': 10,
#  'IbNzF_SIdZioYbLnL6F5Vw': 18,
#  '1m8rFe-BCr6qHSMoV5KkUw': 15,
#  'OQMOgqS1NFIyAW4i66iDYA': 95,
#  'idSvgXVCamuEwbL3sp9O_A': 6,
#  'Sve2h1r-jOyaoGY2GYL0WA': 36,
#  'L-O1rmPXJ3ihCnfgJIigbQ': 8,
#  'NLDDaat42UQXQCOpU4e2TA': 103,
#  'iJUVamUkqL6VfEMfyQoujw': 57,
#  '0o0VMEJeQY0pAAZ9nxErBA': 144,
#  'SWoWXML68esw-UhHRjLBQQ': 65,
#  '_YFr0NsiulAoUOAtARP_Xw': 2,
#  'Rj3LpeiJUPYBC8L_Xy6cBQ': 1,
#  'K5oJ9aQth_Ltg3Awgjy-wA': 35,
#  '2-GIaS8Bc4MHqzXHLQY9Ew': 1,
#  'l2srZt-GNvF7tMotR_VyAw': 2,
#  '3nUQ4xbLlySDbkE03nyp-Q': 46,
#  'yUrJNGlx8V10dRAvdh3ZFw': 1,
#  'eqpoFHtDafP6XBv5ClufLg': 1,
#  'SZN_eQkeLii4VUkjupS9UQ': 2,
#  'd1vSOBq_RauHGpCh7VN7KA': 4,
#  'jfXT_8J_EQnJVa4sJ3z6hg': 12,
#  'GMkF0yJWwFRVO9kiGOcojQ': 47,
#  'cFoiVWF42HSXQEtqxDvdWQ': 5,
#  'rXrJkICbrO7SEvKNZlrPkA': 4,
#  'nGuemQk8wCFyohPz3Z-big': 8,
#  'nN3Ym_sgqI5EQuC4AIJprA': 48,
#  'azj8vFl7JuSyHqamSVhd4A': 13,
#  'u1IC7xORIeAkJEt6n4p3_A': 10,
#  '188v8fiXebMrsPAB4PJ_PQ': 23,
#  'tZL60BEoU-NVHK8OsBiN3Q': 6,
#  'vcywddFwcXuE-cIlQfouiA': 4,
#  'WPjR6viRLglxD_BMztch2g': 17,
#  '2LCrT_BOJvGV4xi_lmoRcA': 81,
#  'PoLTut88ZmgFsnFvsTy5XQ': 11,
#  'XXVfsLunIiz3xDeK17aHFQ': 54,
#  'E5qFR0RBQBoXx8FbrOkdbw': 33,
#  'rmUJGvphy7GXY9Y_kGutgA': 13,
#  'k1ACFw3wmqkNGoiGeNLc0w': 42,
#  'auVkTXPmA8o3oU8barlBSw': 14,
#  'Uf-jZhhEYRIFxzyT1d5R6Q': 7,
#  '377CDhtGrgoNNEnEhf6Ccw': 11,
#  'bX5MJIMxOnfKd_Ex6V9gXA': 2,
#  'xs_fnNe0hofd7ZOupCjesQ': 16,
#  'LcWp2WChE9HpqdMEM8D2VQ': 24,
#  '5y0N0fTEg_ZGEGDGzzRTdg': 18,
#  'nEL-_kLeN37CSR9fXFY4zw': 17,
#  '31tjiU793jocP_DKwn1V8A': 25,
#  '8JC-Yb3UDUv2FUl5ym1nVg': 147,
#  'kkUvJK-Y-Jb7nWjnTRZFVA': 14,
#  'wHg1YkCzdZq9WBJOTRgxHQ': 255,
#  'cFC35FulkCpmFlVrhK8iHw': 6,
#  '_GVAV2LjUWEs9fGjslex_A': 106,
#  'qm5xGd3d47RfLWib0ryMAg': 12,
#  'GrSixRnGIxNUJ1Cn5DNX9A': 197,
#  '_LEQt7oTVjiaXyVHK_MM7g': 59,
#  'N37cYLoF_BQf15fcid35lQ': 1,
#  'z-JC1S58qaW8WNiOzUh_TA': 19,
#  '100Df1wcVrl9rJgB7EG6xw': 99,
#  'YsTdL5RgU0qHHlsyFwDAaA': 2,
#  'hSGAiCRmKSuNIuSsRq0nAQ': 3,
#  'mc5mitfrreuuf7eMe404Kg': 8,
#  'GYUM5OpAH_7pJsvN5lw7wA': 2,
#  'sbNbxmGNodDJukgSXBFD4Q': 9,
#  'tQ5wiJ9TGUbmIqnO4-njWg': 11,
#  'Ti86eeLrIhpNHDpjbla_fA': 20,
#  'kk05snSafuIFK0lsxoMNzA': 88,
#  'viMBWEgaZ0gSUpre0W8rhA': 9,
#  'n6LeAoIuDR3NfIBEsmL_zg': 43,
#  '_k1lZP9bVrmIYpfwLLtZZA': 4,
#  'MZ2xyaW-hMOUzpUcHAUatA': 2,
#  'U_fAIe7CUaGMejwSdNvMgw': 55,
#  'bc1BST38H04S7wvL1SRniw': 2,
#  'ZmIgP4U4Ht9CYmNX0_zP6w': 138,
#  'YMB29SPB8Z_a2be4O5gxOg': 193,
#  'Ovpa3S8xD96dLE5eDxcxJg': 226,
#  'CoO7q1yFPVy-nRqPOYLglA': 3,
#  'FvSVsGNKBgQdQt-MYP3Kxw': 9,
#  'CpvQD8CxglFO6KhqX-MFAg': 3,
#  'CuzADeE8rkYwiWrIxTsNGg': 16,
#  'tKgDgXSkOklBb9tQVGkYhQ': 8,
#  'zMhkzu9VXFULKQ8YCCsDVQ': 18,
#  'V1_3yModtZm-WmHs1zbc7g': 1,
#  'uK9Oh-IgPT4MOCJ69KSRSg': 2,
#  'wysB0lvlJuSBwUAerJqjJQ': 8,
#  'QB49hhSLpPMaZ_rqBjP8uQ': 7,
#  'rdRJ3gejMIz8pB2zyR24oQ': 1,
#  'm7j9e53ycZxjWYBD7rZVng': 123,
#  'nRWHSp7rtXVPCjHxan_h8A': 5,
#  'XwEY9qjfXtdpNbmRY2p_bA': 23,
#  '33vUIil_GCaT92aUaZhRXA': 154,
#  '7oMqFG6Su53dtbkVnF80Gg': 96,
#  'upG0mzEpQFpoSZXRv2pfaw': 1,
#  'z1tNqF5qJRpibGj-9_r9Ew': 91,
#  'WxeD74JGiwjljzHndYSvmw': 30,
#  'AvjnPmsfQWsUFJ4-M9wI1A': 1,
#  'g-lJlj7TNdfoNqtk3r3Ikg': 12,
#  'wLuDGMXytNVTF8ZU2gwUEQ': 74,
#  'zTWH9b_ItSdLOK9ypeFOIw': 4,
#  'sPEFql7fLp0oouFxnooGpQ': 84,
#  'CoQ5qnDp_rLqkBN3U3yxCg': 3,
#  '2nXFEyQ06RfcdAXIPbxuwA': 53,
#  'MUHoBFzwRoXpCpgYSN8KRA': 116,
#  'g9s_yIDg9uA3RufY8-cqtA': 39,
#  'OmnXoXdLsXhOVHQCDX_nAw': 17,
#  'iBO2m9xXivsIbvFnZHsNvg': 109,
#  'yujwS7lAU_2e8z8yQdsqlg': 11,
#  'SwnLshF0NJBRK9UilGA80Q': 13,
#  'QqndsiMnOxuyhaSzIGmq7Q': 1,
#  'Y1yGvKaf3XzQ-oLu-J4-3Q': 7,
#  'X8hjnv-PSuJ0ASItdwpzqg': 17,
#  'O0WWBU6acBCzzYjyXaouUQ': 4,
#  'hNs-x49UQmkN3GSAwKXUGQ': 2,
#  'Bl9i_CBC9orZCmr2NxrlMA': 1,
#  'M6oU3OBf_E6gqlfkLGlStQ': 219,
#  'XAYnVFLCV7i3iR4qs4eeQQ': 6,
#  '1bV0I0j-YzDcfiXK2M-U8A': 19,
#  'FHJUj7EHB9nB2czVOzQX3Q': 85,
#  'IrTcXG-XwBcgrmcBxz2J-Q': 9,
#  'LqgGgWi3FLHBViX9tmZ9sw': 200,
#  'die-1gtgzw5KcyUjKo-VSg': 15,
#  'TLxb5zxzXO-Y0bFB__i53g': 3,
#  'q9U8zvkHbEkMCABvBkQByQ': 1,
#  '3xLRUt8wYKwkqE68Inz3uA': 3,
#  '_nKsyDUIdoTimDPM9aG23w': 7,
#  'AZ8NDHmLWdZGzvMtZXzjkA': 28,
#  'v5k-__wHo2xPI25WO-dcQA': 88,
#  'n1KWJCpVeoTrzcN9iATfKA': 40,
#  'lczLjHO7zIhrmSlOXI3ohg': 54,
#  'FXbDtMtmR3zF50ljxeQueA': 5,
#  '5cVACUA-5e1SYyQ_E2-9iw': 2,
#  'xH5ETGmT8IUaPjbwZmj-Ow': 1,
#  '1S7XdhbZWR17Wy4TBsIzaw': 66,
#  'VL3-X2kM2u2Z7dFo-FXVIA': 7,
#  'XtzSu8tDs_XDVAhO_J1VDw': 14,
#  'VChMRGEsIC675BAjnzq4ZQ': 17,
#  'BQrTHuaYJx-_KslhWT4pVA': 1,
#  '6670GGYK2G11s-D5JQbgzg': 2,
#  'q9XgOylNsSbqZqF_SO3-OQ': 288,
#  'L56wgzkIBP5_zVPHQ9XQCA': 8,
#  '4GdN3itvzmFc_6kib2UzlA': 1,
#  'vuxnLRJLT7EjjwIwycDAoA': 2,
#  'y9IKf7VckFc-fesWuDwgxg': 71,
#  'O5z9K7JNEWWWF5AjBj6ahg': 3,
#  'BQ_WTijKUVgP2x5FzR-paQ': 5,
#  '6ts41fCsDKHbFZaKOMNmVQ': 172,
#  '99Jm9c6QZjvElZznML2Y8A': 9,
#  'u760qQnKAwRkRhq6Fn8yzA': 1,
#  '-q0RFaCkmT6TFxgk0a9dPw': 23,
#  'oy6fdscGSXY2gzRqF9pZxg': 91,
#  'GkWuTgewni9bzPM4HUCO-g': 51,
#  '7o6OfRHsmcv44R1CjAh8dQ': 6,
#  'Ee6n17uyTOYFH39jvWDVCA': 1,
#  '7x9oYPGJUnUic47GJ_ewbg': 1,
#  '6rkICkKa9RlOMy-L8g05fw': 18,
#  'Kmtui6Q9md18Cqk7QHTBOA': 5,
#  '8D408fDn0twwIW6FZ42YWg': 9,
#  'FLdun6KWwAh-gC8VHVZGCw': 44,
#  'xFG4Ca2HHmbxDTkMlmHnjQ': 103,
#  'k6ZQA3DJ2EfZJMmadBlWNw': 54,
#  'yBz5KP3YC7ryiAef6FXNVQ': 1,
#  'EXZrHtmzdtDHtH9MPNEhkw': 8,
#  'raMSkwLdZ-kFea1fTY_-Ew': 83,
#  'bvvLS4Vz5yFuNvGKBV3-1g': 30,
#  'Ejy4fKodyYROIU3fH6SGZA': 8,
#  '7u3eL3IodZLq4a1ORGJmrQ': 26,
#  'zing3W2AVxcHwmBHid-Fcg': 15,
#  'Q4c-HD4iycZGrAnNK6d0tw': 23,
#  'xhqlSHTBbMACpLN7jU1Nrg': 6,
#  'cKEkbRkYcYtWymUF8Zxolw': 15,
#  'LXWAXIeYFIdgd2JVPF-9qA': 110,
#  'tBvrnSCLSpUdCDm5w5GPkg': 90,
#  'qdEXAYozQKtDeleky9NacA': 6,
#  '04bgNBaA08GfHUndweJZSA': 4,
#  '9tVLD8PjH7Wwn_EAmCHzWA': 10,
#  '8eH7olqrxizIdscDZvE-Nw': 2,
#  'ZREYKjErXkcoeqUw6gRQtw': 19,
#  'mCE9nD2NnYrokWMMMDoEdw': 1,
#  'GAW_mbLDbIoZQ0V0ZhWK8Q': 26,
#  '9FbgqZ5u9WTLAs28nNafIQ': 91,
#  'WxO2x4xGbHfeWfU_MbuzTQ': 8,
#  '3ltazFFclBfchSYlctX6iA': 4,
#  'r9_tXmlmmm1OTtEzezcnRQ': 5,
#  'WxqpkFekB8Zd9psbJ5GqAQ': 2,
#  '4-Nju_626eCGQRDmodHUug': 3,
#  'gIEyHQJeyBQ8IhYusvTIGg': 3,
#  'AeucYo8J-rZjcq09Wuqsjw': 166,
#  'nYfpquFWxQC342RenTI3rA': 78,
#  'Xz1w0h7wDI22IZKi-CnrHA': 17,
#  'sfKMl7ERKuwxIh3HLXUg-Q': 24,
#  'HQ5ocr3bT7TrZe8MT3DDSA': 2,
#  'n4Y05XFlXMWVi7xiY62jfg': 2,
#  'Qz_WQ6blpBBSaEwsofbB_w': 34,
#  'k9cMboDc6uqa-6BggMxxaA': 7,
#  'zG7NW5vCKJZRcBR95qEuMw': 40,
#  'pDSMS-IW5wyZK0XBi4jnDw': 38,
#  'kffxYQVQsEpF1DVlQlcGCg': 108,
#  'QqAL6vvUE_lJbAFSucWysA': 7,
#  '3uR5YTXgW4hatuFnaNxSGg': 39,
#  'VBKbZD9X4zruXYORIhJhhg': 73,
#  'BWo7K_QGZCO2PG1osiwRuQ': 39,
#  'YnuPa08WRFw_VYQsb3rcoA': 4,
#  'fiyOnIEKBOgj00NJLwDBVg': 77,
#  'DFOHCl7siB7Jt7ggQ8fEyA': 4,
#  '9wl224U7ZQrNggpWVsiLTg': 7,
#  's0yUJlCABN8oVjcNocRpxg': 5,
#  'onWc8uutW3q9q8KYdxqvZA': 16,
#  'bYZN1gwIQRS_miEPqeV9og': 16,
#  'IMeUbv6u0uIIoMFKBOZhtw': 1,
#  'ZNG23JOioaJs6dbAVWRMfg': 13,
#  'UpHMvyLaYYVPkt7YPnMkWQ': 1,
#  'RQi82OtF2qvOBv6VEE0pyw': 1,
#  'rxNiJzemV2g9mxDEzpWetQ': 1,
#  'N1Q6HiZvnZHjNU712Gymqw': 74,
#  '-7LfdqX286W8zJ01ljY_SQ': 54,
#  'QEDVhdE7tK6aQp1WuJY69g': 3,
#  'pEVf8GRshP9HUkSpizc9LA': 255,
#  'IhcTLLWKS6ZiNyIX9oQQPQ': 66,
#  '34gJ_KlP3RM6jotNT6TcDQ': 90,
#  'UDBYhBP8avCa-2iZb71Ixw': 13,
#  '28MSq7NWzcLCGYXkX2p9KQ': 21,
#  'dbgrCZFswU_5WrKmSTf_fg': 3,
#  'e1ojEz8owjWsHsaxaRiFmg': 3,
#  'qrX3s0BfiHQTH_gmnyysjw': 56,
#  'XpSZrY_Ym8GGx7SNEd0q9g': 55,
#  'QT-7jpsEuCR-pFro59KBtQ': 27,
#  'h2AKBbrycz4bzJ6F8V7a_w': 7,
#  'tdNV2Wb0LrFpm1Yfov_Klw': 200,
#  '0DDWHEWmcYWGIPQ6fvG_xw': 4,
#  'C0vujI9rPTA30iHyBYKlfg': 5,
#  'QHRmdqfrZRlynmlL7k_v4g': 8,
#  '7mXorwoYFPlBvU9qCNuoOg': 2,
#  'crrp9oqSWsVnDHPKgy_bqw': 7,
#  'blgNUB-2AGkVOKHBJ_-1qg': 5,
#  'db7t1HCsqxvwbe3kSoqtYQ': 6,
#  'xdWsnbaTEfBMVHttqZDHxg': 145,
#  '9mjItdXixKECanLV6RBIrw': 47,
#  'fNfLXX_ce2TQPrdHCqPzZQ': 130,
#  'F8MIgcGzop_Mv0gFYJc4fA': 4,
#  'LTX9pmF-zXPYB4wE8b9RZg': 34,
#  'z5GWsidy0WT2CLxwhGiV5A': 4,
#  'yrXCDuHsWLt14ql-aLOCYg': 22,
#  'o6hksardqzx7jZwiNxoRDg': 8,
#  'EsH5xs6wMUQ11oleoPmKfQ': 2,
#  'qkbiaiS8t8YHWx3J04NjSw': 26,
#  'f1EokGAtmy2OChSs1XbETA': 6,
#  'FS_3j3S_QvIaQCAMFKl_7w': 1,
#  'hW2XQMGHy5_TW7dnijZR6Q': 28,
#  'uJVPMnfxx3lYX7kVHUTbTw': 2,
#  '0nCNOQv4VV2qYcqVno5ZrA': 30,
#  'TstEnc6buaP6XLUPMgNH-A': 1,
#  'RHWm_duEdCgWwtN1fBUkHA': 12,
#  'ZrUZtLgLOn15v2NIZl-oKQ': 42,
#  'OsYh3jArm6fgozczE85ZeQ': 83,
#  'sYxD6VdrAaajp-gxim0I_Q': 5,
#  '0rRTTYnjOtMDD32RvlxPow': 10,
#  'I4EIRTgGREZKTMThz1LihA': 1,
#  '31OZmHva7Q0dTNqpM4TKug': 39,
#  'iC7NVBmkzRl4rKEU5MWS0A': 41,
#  '5zd678Uuarx_Xj-0NNSy7g': 5,
#  'SJoMGpnY0DVtMlpjFK78-Q': 29,
#  'YL8SKv-pwx-Wj9cwGYrn3g': 122,
#  'U4j1MmMVZlts04OZxz87SA': 20,
#  'Ovac_Bws19DOy2_ai3WzeA': 15,
#  'Od-H9HkTG4PgWGJP4_pFGw': 9,
#  'zgCO0TnkvfohTmwPTwP7Ew': 143,
#  'BPde0dz-vM4_fZCNPRT8sA': 10,
#  'pv82zTlB5Txsu2Pusu__FA': 139,
#  '6rAzupZ7IYIxkjxpV96A8A': 1,
#  'vN25DTdMDr718zMCAgJvQQ': 19,
#  'HOleI3jz1MLNUJ6cc1x0Pw': 176,
#  'D9aj6AjCyLp-zp8fozL8aQ': 12,
#  'DwU7KVfebA70AlVtX0iOWw': 76,
#  'j2eMum97Tm37YDRIFtQ44A': 5,
#  'QNzDmxyhQjS0wwS2zNACNg': 1,
#  'ddr63wQ7CdByADPnHNr4-w': 8,
#  '2XCsVpAMsGUykrM-BBFEXA': 67,
#  '-Dof9NwAoQwRM-GVPZk5zw': 56,
#  'MhybZXjI3PrrJ2l9QJ5o2w': 1,
#  'byIGqd1Chrzuv8RT0al35A': 1,
#  'Lsygjb8x4QDIFOY6mbNmrg': 1,
#  'DfsrWRuuiET_-CEupb5NdA': 4,
#  'F6QsMoJdvtohlbnST-fDyQ': 111,
#  'Kyc_V-2G77tRfwJsBxwZ4A': 40,
#  '318bjHL6yRQIo4hy4DzRPw': 19,
#  'A99dyhEqcd_yXKPfBWeZHA': 145,
#  '2-W8eFdPPLxS1nD50swCUA': 3,
#  'xxMoW5Xj8mvuqoawsK-l6A': 1,
#  'X_kPh3nt0AJPNPHye2rTlA': 102,
#  'vmvCjcHVTFgLG7rFSuGQjw': 14,
#  ...}

# %%
ratings_count_df=pd.DataFrame(list(ratings_count.items()),columns=['User_id','Count of Ratings'])
print(ratings_count_df[ratings_count_df['Count of Ratings']>=100])
print(ratings_count_df[ratings_count_df['Count of Ratings']>=100].sum()['Count of Ratings'])
# Out:
#                      User_id  Count of Ratings
# 0     rLtl8ZkDX5vH5nAx9C3q5Q               247
# 6     wFweIWhv2fREZV_dYkz_1g               130
# 13    Xm8HXE1JHqscXe5BKf0GFQ               153
# 18    UsULgP4bKA8RMzs8dQzcsA               181
# 19    nDBly08j5URmrHQ2JCbyiw               133
# ...                      ...               ...
# 4435  b4C9E7vTJrOdkJQA86xYSg               123
# 4534  w1LjSa5wMexRIQ-82LKWmQ               100
# 4663  bX5mIrDlyD8ZabvF_An7FA               127
# 6066  zfysCL-0uQNCWdGvzZ6QWA               100
# 6144  PoQOIZc2q5nud7uVz_jdjw               118
#
# [214 rows x 2 columns]
# 35769

# %%
# We want our users to have at least 100 ratings to be considered
RATINGS_CUTOFF = 100
remove_users = []
for user, num_ratings in ratings_count.items():
    if num_ratings < RATINGS_CUTOFF:
        remove_users.append(user)
df_final = data.loc[ ~ data.user_id.isin(remove_users)]

# %%
df_final.shape
# Out:
# (35769, 30)

# %% [markdown]
# **As we have now explored the data, let's start building the Recommendation systems**
#
# ## Model 1: **Building Rank-Based Recommendation System**

# %% [markdown]
# Rank-based recommendation system provides recommendations based on the most popular items. This kind of recommendation system is useful when we have **cold start** problems. Cold start refers to the issue when **we get a new user into the system** and the machine is not able to recommend a restaurant to the new user, as the user did not have any historical interactions in the dataset. In those cases, we can use a rank-based recommendation system to recommend a restaurant to the new user.

# %% [markdown]
# To build the rank-based recommendation system, we take the **average** of all the ratings provided to each restaurant and then rank them based on their average rating.

# %%
# Calculating average ratings
average_rating = data.groupby('business_id').mean()['stars']

# Calculating the count of ratings
count_rating = data.groupby('business_id').count()['stars']

# Making a dataframe with the count and average of ratings
final_rating = pd.DataFrame({'avg_rating': average_rating, 'rating_count': count_rating})

# %%
# Let us see the first 5 records of the final_rating
final_rating.head()
# Out:
#                         avg_rating  rating_count
# business_id
# --5jkZ3-nUPZxUvtcbr8Uw    4.545455            11
# --BlvDO_RG2yElKu9XA1_g    4.162162            37
# -0D_CYhlD2ILkmLR0pBmnA    4.000000             5
# -0QBrNvhrPQCaeo7mTo0zQ    4.333333             3
# -0bUDim5OGuv8R0Qqq6J4A    2.333333             6

# %% [markdown]
# Here I've created a function to find the **top n restaurant** for a recommendation based on the average ratings of the restaurant. You can also add a **threshold for a minimum number of visits** for a restaurant to be considered for recommendation.

# %%
def top_n_restaurant(data, n, min_interaction = 100):
    
    # Finding restautants with minimum number of interactions
    recommendations = data[data['rating_count'] > min_interaction]
    
    # Sorting values with respect to average rating
    recommendations = recommendations.sort_values(by = 'avg_rating', ascending = False)
    
    return recommendations.index[:n]

# %% [markdown]
# We can **use this function with different n's and minimum interactions** to get restaurants to recommend.

# %% [markdown]
# #### **Recommending top 5 restaurant with 50 minimum interactions based on popularity.**

# %%
list(top_n_restaurant(final_rating, 5, 50))
# Out:
# ['8HQ8clouLGgee99KkR4vXA',
#  'CKjcewWeWvdJ7TzOQbZOIw',
#  '97Z7j4vH0kfzL10AONi4uA',
#  '_TekkyyFeX_8MBepPIxuTg',
#  'L-uPZxooP_ziXCtRrWi8Pw']

# %% [markdown]
# In this was  **the Rank-Based Recommendation System** can be used to solve the problem of cold start. In the next section, I implement **Collaborative Filtering Based Recommendation System**.

# %% [markdown]
# ## **Collaborative Filtering Based Recommendation System**.

# %% [markdown]
# In this type of recommendation system, `we do not need any information` about the users or items. There is no information about characteristics of the customers or restaurants.
# We only need user item interaction data to build a collaborative recommendation system. For example -
# <ol>
#     <li><b>Ratings</b> provided by users. For example - ratings of books on goodread, movie ratings on imdb etc.</li>
#     <li><b>Likes</b> of users on different facebook posts, likes on youtube videos.</li>
#     <li><b>Use/buying</b> of a product by users. For example - buying different items on e-commerce sites.</li>
#     <li><b>Reading</b> of articles by readers on various blogs.</li>
# </ol>

# %% [markdown]
# #### Types of Collaborative Filtering

# %% [markdown]
# - Similarity/Neighborhood-based
#  * User-User Similarity-Based
#  * Item-Item Similarity-based
# - Model based

# %% [markdown]
# ### **Building a baseline user-user similarity based recommendation system.**

# %% [markdown]
# - Below I've built **similarity-based recommendation systems** using `cosine` similarity and using **KNN to find similar users** which are the nearest neighbor to the given user.
# - I've used - `surprise` library to build the remaining models, let's first import the necessary classes and functions from this library.
#
#
# **!pip install surprise**

# %%
# !pip install surprise
# Out:
# Requirement already satisfied: surprise in c:\users\rutuj\anaconda3\lib\site-packages (0.1)
# Requirement already satisfied: scikit-surprise in c:\users\rutuj\anaconda3\lib\site-packages (from surprise) (1.1.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\rutuj\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.1.0)
# Requirement already satisfied: numpy>=1.11.2 in c:\users\rutuj\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.20.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\rutuj\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.16.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\rutuj\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.6.1)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\rutuj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rutuj\anaconda3\lib\site-packages)

# %%
# To compute the accuracy of models
from surprise import accuracy

# This class is used to parse a file containing ratings, data should be in structure - user; item; rating
from surprise.reader import Reader

# Class for loading datasets
from surprise.dataset import Dataset

# For tuning model hyperparameters
from surprise.model_selection import GridSearchCV

# For splitting the rating data in train and test datasets
from surprise.model_selection import train_test_split

# For implementing similarity-based recommendation system
from surprise.prediction_algorithms.knns import KNNBasic

# For implementing matrix factorization based recommendation system
from surprise.prediction_algorithms.matrix_factorization import SVD

# For implementing K-Fold cross-validation
from surprise.model_selection import KFold

# For implementing clustering-based recommendation system
from surprise import CoClustering

# %% [markdown]
# **Before building the recommendation systems, let's understand some basic terminologies we will be using here.**

# %% [markdown]
# **Relevant item:** An item (product in this case) that is actually **rated higher than the threshold rating (here 3.5)** is relevant, if the **actual rating is below the threshold then it is a non-relevant item**.
#
# **Recommended item:** An item that's **predicted rating is higher than the threshold (here 3.5) is a recommended item**, if the **predicted rating is below the threshold then that product will not be recommended to the user**.

# %% [markdown]
# **False Negative (FN):** It is the **frequency of relevant items that are not recommended to the user**. If the relevant items are not recommended to the user, then the user might not buy the product/item. This would result in the **loss of opportunity for the service provider**, which the company would like to minimize.
#
# **False Positive (FP):** It is the **frequency of recommended items that are actually not relevant**. In this case, the recommendation system is not doing a good job of finding and recommending the relevant items to the user. This would result in **loss of resources for the service provider**, which they would also like to minimize.

# %% [markdown]
# **Recall:** It is the **fraction of actually relevant items that are recommended to the user**, i.e., if out of 10 relevant products, 6 are recommended to the user then recall is 0.60. Higher the value of recall better is the model. It is one of the metrics to do the performance assessment of classification models.
#
# **Precision:** It is the **fraction of recommended items that are relevant actually**, i.e., if out of 10 recommended items, 6 are found relevant by the user then precision is 0.60. The higher the value of precision better is the model. It is one of the metrics to do the performance assessment of classification models.

# %% [markdown]
# **In terms of how many recommendations are relevant and vice-versa, below are some most used performance metrics used in the assessment of recommendation systems.**

# %% [markdown]
# ### **Precision@k, Recall@ k, and F1-score@k**

# %% [markdown]
# **Precision@k** - It is the **fraction of recommended items that are relevant in `top k` predictions**. The value of k is the number of recommendations to be provided to the user. One can choose a variable number of recommendations to be given to a unique user.
#
#
# **Recall@k** - It is the **fraction of relevant items that are recommended to the user in `top k` predictions**.
#
# **F1-score@k** - It is the **harmonic mean of Precision@k and Recall@k**. When **precision@k and recall@k both seem to be important** then it is useful to use this metric because it is representative of both of them.

# %% [markdown]
# ### **Some useful functions**

# %% [markdown]
# - Below function takes the **recommendation model** as input and gives the **precision@k and recall@k** for that model.
# - To compute **precision and recall**, **top k** predictions are taken under consideration for each user.

# %%
def precision_recall_at_k(model, k = 10, threshold = 3.5):
    """Returns precision and recall at k metrics for each user."""

    # First map the predictions to each user
    user_est_true = defaultdict(list)
    
    # Making predictions on the test data
    predictions = model.test(testset)
    
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key = lambda x: x[0], reverse = True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant. When n_rec_k is 0, 
        # Precision is undefined. We here set Precision to 0 when n_rec_k is 0

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended. When n_rel is 0, 
        # Recall is undefined. We here set Recall to 0 when n_rel is 0

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0
    
    # Mean of all the predicted precisions are calculated
    precision = round((sum(prec for prec in precisions.values()) / len(precisions)), 3)
    
    # Mean of all the predicted recalls are calculated
    recall = round((sum(rec for rec in recalls.values()) / len(recalls)), 3)
    
    accuracy.rmse(predictions)

    # Command to print the overall precision
    print('Precision: ', precision)

    # Command to print the overall recall
    print('Recall: ', recall)

    # Formula to compute the F-1 score
    print('F_1 score: ', round((2*precision * recall) / (precision + recall), 3))

# %% [markdown]
# Below we are loading the **dataset**, which is a **pandas dataframe**, into a **different format called `surprise.dataset.DatasetAutoFolds`** which is required by this library. To do this we will be **using the classes `Reader` and `Dataset`**.

# %%
# Instantiating Reader scale with expected rating scale
reader = Reader(rating_scale = (0, 5))

# Loading the dataset
data = Dataset.load_from_df(df_final[['user_id', 'business_id', 'stars']], reader)

# Splitting the data into train and test datasets
trainset, testset = train_test_split(data, test_size = 0.2, random_state = 42)

# %%
trainset

# %% [markdown]
# - Now we are **ready to build the first baseline similarity-based recommendation system** using the cosine similarity.
# - **KNNBasic** is an algorithm that is also **associated with the surprise package**, it is used to find the **desired similar items among a given set of items**.

# %% [markdown]
# - To compute **precision and recall**, a **threshold of 3.5 and k value of 10 is taken for the recommended and relevant ratings**.
# - In the **present case precision and recall both need to be optimized as the service provider would like to minimize both the losses discussed** above. Hence, the correct performance measure is the **F_1 score**.

# %% [markdown]
# ## Model 2: **Building User-User Collaborative Filtering Model**

# %%
# Declaring the similarity options
sim_options = {'name': 'cosine',
               'user_based': True}

# KNN algorithm is used to find desired similar items
sim_user_user = KNNBasic(sim_options = sim_options, verbose = False, random_state = 1)

# Train the algorithm on the trainset, and predict ratings for the testset
sim_user_user.fit(trainset)

# Let us compute precision@k, recall@k, and f_1 score with k = 10
precision_recall_at_k(sim_user_user)
# Out:
# RMSE: 1.0409
# Precision:  0.773
# Recall:  0.417
# F_1 score:  0.542

# %% [markdown]
# - We have calculated **RMSE** to check **how far the overall predicted ratings** are from the **actual ratings**.
# - Intuition of Recall - We are getting a **recall of almost 0.42**, which means out of **all the relevant restaurants, 42% are recommended**.
# - Intuition of Precision - We are getting a **precision of almost 0.773**, which means **out of all the recommended restaurants 77.3% are relevant**.
# - Here **F_1 score** of the **baseline model is almost 0.542**. It indicates that **mostly recommended restaurants were relevant and relevant restaurants were recommended** to the user. We will try to improve this later by using **GridSearchCV by tuning different hyperparameters** of this algorithm.

# %% [markdown]
# Let's now **predict rating for a user with `userId = rLtl8ZkDX5vH5nAx9C3q5Q` and `businessId = 9yKzy9PApeiPPOUJEtnvkg`** as shown below.

# %%
# Predicting rating for a sample user with a visited restaurant
sim_user_user.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 3.77   {'actual_k': 16, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=3.7675091038953616, details={'actual_k': 16, 'was_impossible': False})

# %% [markdown]
# - The above output shows that **the actual rating for this user-item pair is 5 and the predicted rating is 3.77** by the **user-user-similarity-based baseline model**. This implies that the model is under-estimating the ratings.

# %% [markdown]
# Below we are **predicting rating for the same `userId = rLtl8ZkDX5vH5nAx9C3q5Q` but for a restaurant which this user has not seen yet, i.e., `business_id = zp713qNhx8d9KCJJnrw1xA`**

# %%
# Predicting rating for a sample user with a restaurant that is not-visited by the user
sim_user_user.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 3.87   {'actual_k': 28, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=3.873369257511826, details={'actual_k': 28, 'was_impossible': False})

# %% [markdown]
# ### **Improving similarity-based recommendation system by tuning its hyper-parameters**

# %% [markdown]
# Below we will be tuning hyperparameters for the `KNNBasic` algorithm. Let's try to understand some of the hyperparameters of the KNNBasic algorithm:

# %% [markdown]
# - **k** (int) – The (max) number of neighbors to take into account for aggregation. The default value for k is 40.
# - **min_k** (int) – The minimum number of neighbors to take into account for aggregation. If there are not enough neighbors, the prediction is set to the global mean of all ratings. The default value for min_k is 1.
# - **sim_options** (dict) – A dictionary of options for the similarity measure. And there are four similarity measures available in surprise -
#     - cosine
#     - msd (default)
#     - Pearson
#     - Pearson baseline

# %%
# Setting up the parameters grid to tune the hyperparameters
param_grid = {'k': [20, 30, 40], 'min_k': [3, 6, 9],
              'sim_options': {'name': ['msd', 'cosine'],
                              'user_based': [True]}
              }

# Performing 3-fold cross validation to tune the hyperparameters
gs = GridSearchCV(KNNBasic, param_grid, measures = ['rmse'], cv = 3, n_jobs = -1)

# Fitting the model on the data
gs.fit(data)

# Print the best RMSE score
print(gs.best_score['rmse'])

# Print the combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.017292322235514
# {'k': 40, 'min_k': 6, 'sim_options': {'name': 'msd', 'user_based': True}}

# %% [markdown]
# Once the grid search is **complete**, we can get the **optimal values for each of those hyperparameters** as shown above.

# %% [markdown]
# Now let's build the **final model by using tuned values of the hyperparameters** which we received by using **grid search cross-validation**.

# %%
# Using the optimal similarity measure for user-user-based collaborative filtering
sim_options = {'name': 'cosine',
               'user_based': True}

# Creating an instance of KNNBasic with optimal hyperparameter values
sim_user_user_optimized = KNNBasic(sim_options = sim_options, k = 40, min_k = 6, random_state = 1, verbose = False)

# Training the algorithm on the trainset
sim_user_user_optimized.fit(trainset)

# Let us compute precision@k and recall@k also with k = 10
precision_recall_at_k(sim_user_user_optimized)
# Out:
# RMSE: 1.0060
# Precision:  0.762
# Recall:  0.413
# F_1 score:  0.536

# %% [markdown]
# - We can see from above that after tuning hyperparameters, **F_1 score of the tuned model has reduced a bit as compared to the baseline model.**

# %% [markdown]
# Let's us now **predict rating for a user with `userId` = "rLtl8ZkDX5vH5nAx9C3q5Q", and business_id = "9yKzy9PApeiPPOUJEtnvkg" with the optimized model as shown below**.

# %%
sim_user_user_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 3.77   {'actual_k': 16, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=3.7675091038953616, details={'actual_k': 16, 'was_impossible': False})

# %% [markdown]
# Below we are predicting rating for the same **`userId = "rLtl8ZkDX5vH5nAx9C3q5Q"`** but for a restaurant which this user has **not visited before**, i.e., `business_id = zp713qNhx8d9KCJJnrw1xA`, by using the **optimized model** as shown below -

# %%
sim_user_user_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 3.87   {'actual_k': 28, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=3.873369257511826, details={'actual_k': 28, 'was_impossible': False})

# %% [markdown]
# ### **Identifying similar users to a given user (nearest neighbors)**

# %% [markdown]
# We can also find out **similar users to a given user** or its **nearest neighbors** based on this KNNBasic algorithm. Below we are finding the 5 most similar users to the first user in the list with internal id 0.

# %%
# Here 0 is the internal id of the above user
sim_user_user_optimized.get_neighbors(0, 5)
# Out:
# [18, 52, 79, 97, 103]

# %% [markdown]
# ### **Implementing the recommendation algorithm based on optimized KNNBasic model**

# %% [markdown]
# Below we will be implementing a function where the input parameters are -
#
# - data: A **rating** dataset.
# - user_id: A user id **for which we want the recommendations**.
# - top_n: The **number of items we want to recommend**.
# - algo: The algorithm we want to use **for predicting the ratings**.
# - The output of the function is a **set of top_n items** recommended for the given user_id based on the given algorithm.

# %%
# Let us see first 5 records of the df_final dataframe
df_final.head()
# Out:
#     business_blank                                business_categories  \
# 0            False                    Breakfast & Brunch; Restaurants
# 6            False                               Mexican; Restaurants
# 13           False                              Tattoo; Beauty & Spas
# 18           False  Nightlife; Breakfast & Brunch; Mexican; Bars; ...
# 19           False          Hotels & Travel; Airlines; Transportation
#
#    business_city                              business_full_address  \
# 0        Phoenix                  6106 S 32nd St\nPhoenix, AZ 85042
# 6        Phoenix                  1919 N 16th St\nPhoenix, AZ 85006
# 13         Tempe                961 E Guadalupe Rd\nTempe, AZ 85283
# 18    Scottsdale             3313 N Hayden Rd\nScottsdale, AZ 85251
# 19       Phoenix  Phoenix Sky Harbor Airport\nTerminal 3\nPhoeni...
#
#                business_id  business_latitude  business_longitude  \
# 0   9yKzy9PApeiPPOUJEtnvkg          33.390792         -112.012504
# 6   zp713qNhx8d9KCJJnrw1xA          33.469132         -112.047512
# 13  WGNIYMeXPyoWav1APUq7jA          33.363760         -111.927299
# 18  b5cEoKR8iQliq-yT2_O0LQ          33.486918         -111.908738
# 19  4JzzbSbK9wmlOBJZWYfuCg          33.439648         -112.026154
#
#     business_neighborhoods  business_open  business_review_count  ...  \
# 0                      NaN           True                    116  ...
# 6                      NaN           True                    307  ...
# 13                     NaN           True                     25  ...
# 18                     NaN           True                    262  ...
# 19                     NaN           True                     13  ...
#
#     reviewer_funny reviewer_name reviewer_review_count  reviewer_type  \
# 0              331         Jason                   376           user
# 6             1187       Monique                   295           user
# 13             702         Lucky                   458           user
# 18            1057         Sarah                   260           user
# 19             504          Bill                   219           user
#
#    reviewer_useful  stars                                               text  \
# 0             1034      5  My wife took me here on my birthday for breakf...
# 6             1376      5  Drop what you're doing and drive here. After I...
# 13            1113      4  Good tattoo shop. Clean space, multiple artist...
# 18            1657      3  I met a friend for lunch yesterday. \n\nLoved ...
# 19             596      4  They've gotten better and better for me in the...
#
#       type  useful                 user_id
# 0   review       5  rLtl8ZkDX5vH5nAx9C3q5Q
# 6   review       7  wFweIWhv2fREZV_dYkz_1g
# 13  review       2  Xm8HXE1JHqscXe5BKf0GFQ
# 18  review       6  UsULgP4bKA8RMzs8dQzcsA
# 19  review       1  nDBly08j5URmrHQ2JCbyiw
#
# [5 rows x 30 columns]

# %%
def get_recommendations(data, user_id, top_n, algo):
    
    # Creating an empty list to store the recommended restaurant ids
    recommendations = []
    
    # Creating an user item interactions matrix
    user_item_interactions_matrix = data.pivot_table(index = 'user_id', columns = 'business_id', values = 'stars')
    
    # Extracting those restaurant ids which the user_id has not visited yet
    non_interacted_products = user_item_interactions_matrix.loc[user_id][user_item_interactions_matrix.loc[user_id].isnull()].index.tolist()
    
    # Looping through each of the restaurant ids which user_id has not interacted yet
    for item_id in non_interacted_products:
        
        # Predicting the ratings for those non visited restaurant ids by this user
        est = algo.predict(user_id, item_id).est
        
        # Appending the predicted ratings
        recommendations.append((item_id, est))

    # Sorting the predicted ratings in descending order
    recommendations.sort(key = lambda x: x[1], reverse = True)

    # Returing top n highest predicted rating restaurants for this user
    return recommendations[:top_n]

# %% [markdown]
# #### **Predicted top 5 business/product for userId = "rLtl8ZkDX5vH5nAx9C3q5Q" with similarity based recommendation system**

# %%
# Making top 5 recommendations for user_id "rLtl8ZkDX5vH5nAx9C3q5Q" with a similarity-based recommendation engine
recommendations = get_recommendations(df_final, "rLtl8ZkDX5vH5nAx9C3q5Q", 5, sim_user_user)

# %%
# Building the dataframe for above recommendations with columns "business_id" and "predicted_ratings"
pd.DataFrame(recommendations, columns = ['business_id', 'predicted_ratings'])
# Out:
#               business_id  predicted_ratings
# 0  --5jkZ3-nUPZxUvtcbr8Uw                  5
# 1  -7XuLxfYwZ9x72mEKXdv0A                  5
# 2  -A82xEVAjOYZtDdRQw1FQw                  5
# 3  -CZ78c-H3tTxpP-uQ09CWw                  5
# 4  -J0jhpG0rv4saq9OMh8gXw                  5

# %% [markdown]
# ### **Correcting the Ratings and Ranking the above products/ businesses**

# %% [markdown]
# While comparing the ratings of two products, it is not only the **ratings** that describe the **likelihood of the user to that product**. Along with the rating the **number of users who have seen that product** also becomes important to consider. Due to this, we have calculated the **"corrected_ratings"** for each product. Commonly higher the **"rating_count" of a product more it is liked by users**. To interpret the above concept, a **product rated 4 by 3 people is less liked in comparison to a product rated 3 by 50 people**. It has been **empirically found that the likelihood of the product is directly proportional to the inverse of the square root of the rating_count of the product**.

# %%
def ranking_products(recommendations, final_rating):
  
  # Sort the products based on ratings count
    ranked_products = final_rating.loc[[items[0] for items in recommendations]].sort_values('rating_count', ascending = False)[['rating_count']].reset_index()

  # Merge with the recommended businesses to get predicted ratings
    ranked_products = ranked_products.merge(pd.DataFrame(recommendations, columns = ['business_id', 'predicted_ratings']), on = 'business_id', how = 'inner')

  # Rank the businesses based on corrected ratings
    ranked_products['corrected_ratings'] = ranked_products['predicted_ratings'] - 1 / np.sqrt(ranked_products['rating_count'])

  # Sort the businesses based on corrected ratings
    ranked_products = ranked_products.sort_values('corrected_ratings', ascending = False)
  
    return ranked_products

# %% [markdown]
# **Note:** In the **above-corrected rating formula**, we can add the **quantity `1 / np.sqrt(n)` instead of subtracting it to get more optimistic predictions**. But here we are **subtracting this quantity**, as there are some products with ratings 5 and **we can't have a rating more than 5 for a product**.

# %%
# Applying the ranking products function and sorting it based on corrected ratings
ranking_products(recommendations, final_rating)
# Out:
#               business_id  rating_count  predicted_ratings  corrected_ratings
# 0  --5jkZ3-nUPZxUvtcbr8Uw            11                  5           4.698489
# 1  -J0jhpG0rv4saq9OMh8gXw             6                  5           4.591752
# 2  -7XuLxfYwZ9x72mEKXdv0A             5                  5           4.552786
# 3  -A82xEVAjOYZtDdRQw1FQw             5                  5           4.552786
# 4  -CZ78c-H3tTxpP-uQ09CWw             3                  5           4.422650

# %% [markdown]
# ### Model 3: **Building Item Item Collaborative Filtering Model**

# %% [markdown]
# * Above we have seen **similarity-based collaborative filtering** where similarity has seen **between the users**. Now let us look into similarity-based collaborative filtering where similarity is seen **between the items**.

# %%
# Declaring the similarity options
sim_options = {'name': 'cosine',
               'user_based': False}

# KNN algorithm is used to find desired similar items
sim_item_item = KNNBasic(sim_options = sim_options, random_state = 1, verbose = False)

# Train the algorithm on the trainset, and predict ratings for the testset
sim_item_item.fit(trainset)

# Let us compute precision@k, recall@k, and f_1 score with k = 10
precision_recall_at_k(sim_item_item)
# Out:
# RMSE: 1.0218
# Precision:  0.663
# Recall:  0.344
# F_1 score:  0.453

# %% [markdown]
# - The baseline model is giving an F_1 score of **about 45%**. We will try to **improve this later by using GridSearchCV** by tuning different hyperparameters of this algorithm.

# %% [markdown]
# Let's now **predict a rating for a user with `userId = rLtl8ZkDX5vH5nAx9C3q5Q` and `business_Id = 9yKzy9PApeiPPOUJEtnvkg`** as shown below. Here the user has already interacted or visited the restaurant with businessId "9yKzy9PApeiPPOUJEtnvkg".

# %%
# Predicting rating for a sample user with a visited restaurant
sim_item_item.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 3.48   {'actual_k': 40, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=3.475, details={'actual_k': 40, 'was_impossible': False})

# %% [markdown]
# Below we are **predicting rating for the same `userId = rLtl8ZkDX5vH5nAx9C3q5Q` but for a restaurant which this user has not visited yet, i.e., `business_id = zp713qNhx8d9KCJJnrw1xA`**

# %%
# Predicting rating for a sample user with restaurant not visited by the user
sim_item_item.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 3.77   {'actual_k': 40, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=3.775, details={'actual_k': 40, 'was_impossible': False})

# %% [markdown]
# ### **Improving similarity-based recommendation system by tuning its hyper-parameters**

# %% [markdown]
# Below we will be **tuning hyperparameters for the `KNNBasic` algorithms**.

# %%
# Setting up parameter grid to tune the hyperparameters
param_grid = {'k': [10, 20, 30], 'min_k': [3, 6, 9],
              'sim_options': {'name': ['msd', 'cosine'],
                              'user_based': [False]}
              }

# Performing 3-fold cross validation to tune the hyperparameters
gs = GridSearchCV(KNNBasic, param_grid, measures = ['rmse'], cv = 3, n_jobs = -1)

# Fitting the model on the data
gs.fit(data)

# Print the best RMSE score
print(gs.best_score['rmse'])

# Print the combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.0085563981558672
# {'k': 30, 'min_k': 9, 'sim_options': {'name': 'msd', 'user_based': False}}

# %% [markdown]
# Once the **grid search** is complete, we can get the **optimal values for each of those hyperparameters as shown above**

# %% [markdown]
# Now let's build the **final model** by using **tuned values of the hyperparameters** which we received by using grid search cross-validation.

# %%
# Using the optimal similarity measure for item-item based collaborative filtering
sim_options = {'name': 'msd',
               'user_based': False}

# Creating an instance of KNNBasic with optimal hyperparameter values
sim_item_item_optimized = KNNBasic(sim_options = sim_options, k = 30, min_k = 9, random_state = 1, verbose = False)

# Training the algorithm on the trainset
sim_item_item_optimized.fit(trainset)

# Let us compute precision@k and recall@k also with k = 10
precision_recall_at_k(sim_item_item_optimized)
# Out:
# RMSE: 0.9986
# Precision:  0.708
# Recall:  0.375
# F_1 score:  0.49

# %% [markdown]
# - We can see from above that after tuning hyperparameters, **F_1 score of the tuned model is much better than the baseline model**. Also, there is a considerable fall in the RMSE value after tuning the hyperparameters. Hence the tuned model is doing better than the earlier one.

# %% [markdown]
# Let's us now predict **rating for an user with `userId = rLtl8ZkDX5vH5nAx9C3q5Q` and for `business_id = 9yKzy9PApeiPPOUJEtnvkg`** with the **optimized model** as shown below.

# %%
sim_item_item_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 4.90   {'actual_k': 30, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=4.896024464831805, details={'actual_k': 30, 'was_impossible': False})

# %% [markdown]
# - Here the optimized model is predicting a good rating (almost **4.90**) for the business whose actual rating is 5.

# %% [markdown]
# Below we are **predicting rating** for the same **`userId = rLtl8ZkDX5vH5nAx9C3q5Q`** but for a restaurant which this user **has not visited before**, i.e., `business_id == zp713qNhx8d9KCJJnrw1xA`, by using the optimized model as shown below -

# %%
sim_item_item_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 3.71   {'actual_k': 30, 'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=3.705302758867788, details={'actual_k': 30, 'was_impossible': False})

# %% [markdown]
# - For an unknown business the model is predicting a rating of **3.71**.

# %% [markdown]
# ### **Identifying similar users to a given user (nearest neighbors)**

# %% [markdown]
# We can also find out **similar users** to a given user or its nearest neighbors based on this **KNNBasic algorithm**. Below we are finding 5 most similar users to the user with internal id 0 based on the `msd` distance metric

# %%
sim_item_item_optimized.get_neighbors(0, k = 5)
# Out:
# [21, 27, 35, 51, 57]

# %% [markdown]
# #### **Predicted top 5 business/product for userId = "rLtl8ZkDX5vH5nAx9C3q5Q" with similarity based recommendation system.

# %%
# Making top 5 recommendations for user_id rLtl8ZkDX5vH5nAx9C3q5Q with similarity-based recommendation engine
recommendations = get_recommendations(df_final, "rLtl8ZkDX5vH5nAx9C3q5Q", 5, sim_item_item_optimized)

# %%
# Building the dataframe for above recommendations with columns "business_id" and "predicted_ratings"
pd.DataFrame(recommendations, columns = ['business_id', 'predicted_ratings'])
# Out:
#               business_id  predicted_ratings
# 0  5Q49MxuWJgXS649i7i2Iow           4.416667
# 1  SmY_Xw31b2xyzsKbimQiHQ           4.346154
# 2  N6ff0yyo9Cv_7XPz-YDoow           4.308696
# 3  UmFnmIoLCRe1ywY0bzpRrQ           4.307692
# 4  p204PQg45gECcYwxCAK1wA           4.307692

# %%
# Applying the ranking_products function and sorting it based on corrected ratings
ranking_products(recommendations, final_rating)
# Out:
#               business_id  rating_count  predicted_ratings  corrected_ratings
# 1  5Q49MxuWJgXS649i7i2Iow            10           4.416667           4.100439
# 0  SmY_Xw31b2xyzsKbimQiHQ            15           4.346154           4.087955
# 2  N6ff0yyo9Cv_7XPz-YDoow             7           4.308696           3.930731
# 3  UmFnmIoLCRe1ywY0bzpRrQ             4           4.307692           3.807692
# 4  p204PQg45gECcYwxCAK1wA             3           4.307692           3.730342

# %% [markdown]
# * Now as we have seen **similarity-based collaborative filtering algorithms**, let us now get into **model-based collaborative filtering algorithms**.

# %% [markdown]
# ### Model 4: **Building Model Based Collaborative Filtering Recommendation System - Matrix Factorization**

# %% [markdown]
# Model-based Collaborative Filtering is a **personalized recommendation system**, the recommendations are based on the past behavior of the user and it is not dependent on any additional information. We use **latent features** to find recommendations for each user.

# %% [markdown]
# ### **Singular Value Decomposition (SVD)**

# %% [markdown]
# SVD is used to **compute the latent features** from the **user-item interaction matrix**. But SVD does not work when values are missing in the **user-item interaction matrix**.

# %% [markdown]
# ### **Building a baseline matrix factorization recommendation system**

# %%
# Using SVD matrix factorization
svd = SVD(random_state = 1)

# Training the algorithm on the trainset
svd.fit(trainset)

# Let us compute precision@k and recall@k with k = 10
precision_recall_at_k(svd)
# Out:
# RMSE: 0.9630
# Precision:  0.77
# Recall:  0.383
# F_1 score:  0.512

# %% [markdown]
# - The baseline model with the algorithm is giving a nice F-1 score (almost **51%**). It indicates a good performance by the model.

# %% [markdown]
# - Let's now predict the rating for a user with **`userId = "rLtl8ZkDX5vH5nAx9C3q5Q`"** and **`business_id = "9yKzy9PApeiPPOUJEtnvkg"`** as shown below. Here the user has already rated..

# %%
# Making the prediction
svd.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 4.16   {'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=4.155179595069889, details={'was_impossible': False})

# %% [markdown]
# As we can see - **the actual rating** for this user-item pair is 5 and the predicted rating is also close to that. It seems like we have under-estimated the rating. We will try to fix this later by **tuning the hyperparameters** of the model using GridSearchCV.

# %% [markdown]
# Below we are predicting rating for the same `userId = rLtl8ZkDX5vH5nAx9C3q5Q` but for a restaurant which this user has not seen before, i.e., `business_id = zp713qNhx8d9KCJJnrw1xA`, as shown below -

# %%
# Making prediction using the svd model
svd.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 4.09   {'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=4.09204353877637, details={'was_impossible': False})

# %% [markdown]
# We can see that the **estimated rating** for this **user-item pair** is ~4.10 based on this **matrix factorization based baseline model**.

# %% [markdown]
# ### **Improving matrix factorization-based recommendation system by tuning its hyper-parameters.**

# %% [markdown]
# In SVD, rating is predicted as -

# %% [markdown]
# $$\hat{r}_{u i}=\mu+b_{u}+b_{i}+q_{i}^{T} p_{u}$$

# %% [markdown]
# If user $u$ is unknown, then the bias $b_{u}$ and the factors $p_{u}$ are assumed to be zero. The same applies for item $i$ with $b_{i}$ and $q_{i}$.

# %% [markdown]
# To estimate all the unknown, we minimize the following regularized squared error:

# %% [markdown]
# $$\sum_{r_{u i} \in R_{\text {train }}}\left(r_{u i}-\hat{r}_{u i}\right)^{2}+\lambda\left(b_{i}^{2}+b_{u}^{2}+\left\|q_{i}\right\|^{2}+\left\|p_{u}\right\|^{2}\right)$$

# %% [markdown]
# The minimization is performed by a very straightforward **stochastic gradient descent**:

# %% [markdown]
# $$\begin{aligned} b_{u} & \leftarrow b_{u}+\gamma\left(e_{u i}-\lambda b_{u}\right) \\ b_{i} & \leftarrow b_{i}+\gamma\left(e_{u i}-\lambda b_{i}\right) \\ p_{u} & \leftarrow p_{u}+\gamma\left(e_{u i} \cdot q_{i}-\lambda p_{u}\right) \\ q_{i} & \leftarrow q_{i}+\gamma\left(e_{u i} \cdot p_{u}-\lambda q_{i}\right) \end{aligned}$$

# %% [markdown]
# There are many hyperparameters to tune in this algorithm, you can find a full list of hyperparameters [here](https://surprise.readthedocs.io/en/stable/matrix_factorization.html#surprise.prediction_algorithms.matrix_factorization.SVD)

# %% [markdown]
# Below we will be tuning only three hyperparameters -
# - **n_epochs**: The number of iterations of the SVD algorithm.
# - **lr_all**: The learning rate for all parameters.
# - **reg_all**: The regularization term for all parameters.

# %%
# Set the parameter space to tune
param_grid = {'n_epochs': [10, 20, 30], 'lr_all': [0.001, 0.005, 0.01],
              'reg_all': [0.2, 0.4, 0.6]}

# Performing 3-fold gridsearch cross validation
gs = GridSearchCV(SVD, param_grid, measures = ['rmse'], cv = 3, n_jobs = -1)

# Fitting the model on the data
gs.fit(data)

# Print the best RMSE score
print(gs.best_score['rmse'])

# Print the combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.9585148323729756
# {'n_epochs': 30, 'lr_all': 0.01, 'reg_all': 0.2}

# %% [markdown]
# Once the **grid search** is complete, we can get the **optimal values** for each of those hyperparameters as shown above.

# %% [markdown]
# Now we will **build the final model** by using **tuned values** of the hyperparameters which we received by using grid search cross-validation.

# %%
# Building the optimized SVD model using optimal hyperparameter search
svd_optimized = SVD(n_epochs = 20, lr_all = 0.01, reg_all = 0.2, random_state = 1)

# Training the algorithm on the trainset
svd_optimized = svd_optimized.fit(trainset)

# Let us compute precision@k and recall@k also with k = 10
precision_recall_at_k(svd_optimized)
# Out:
# RMSE: 0.9507
# Precision:  0.79
# Recall:  0.402
# F_1 score:  0.533

# %% [markdown]
# - We can see from above that the **tuned model** is showing a slightly better F_1 score than the baseline model, also the RMSE has gone down. Hence the tuned model is doing better than the earlier model.

# %% [markdown]
# Let's now predict a rating for a user with `userId = rLtl8ZkDX5vH5nAx9C3q5Q` and `BusinessId = 9yKzy9PApeiPPOUJEtnvkg` with the optimized model as shown below.

# %%
# Using svd_algo_optimized model to recommend for userId "rLtl8ZkDX5vH5nAx9C3q5Q" and business_Id 9yKzy9PApeiPPOUJEtnvkg
svd_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "9yKzy9PApeiPPOUJEtnvkg", r_ui = 5, verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: 9yKzy9PApeiPPOUJEtnvkg r_ui = 5.00   est = 3.91   {'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='9yKzy9PApeiPPOUJEtnvkg', r_ui=5, est=3.9075441937737696, details={'was_impossible': False})

# %% [markdown]
# - The predicted rating is good here for a restaurant whose actual rating is **5**. The optimized model is giving a fairly good prediction.

# %%
# Using svd_optimized model to recommend for userId "rLtl8ZkDX5vH5nAx9C3q5Q" and businessId "zp713qNhx8d9KCJJnrw1xA" which the user has not visited
svd_optimized.predict("rLtl8ZkDX5vH5nAx9C3q5Q", "zp713qNhx8d9KCJJnrw1xA", verbose = True)
# Out:
# user: rLtl8ZkDX5vH5nAx9C3q5Q item: zp713qNhx8d9KCJJnrw1xA r_ui = None   est = 3.96   {'was_impossible': False}
# Prediction(uid='rLtl8ZkDX5vH5nAx9C3q5Q', iid='zp713qNhx8d9KCJJnrw1xA', r_ui=None, est=3.963060797712287, details={'was_impossible': False})

# %% [markdown]
# - For an unseen restaurant the rating given by the optimized model seems to be good.

# %%
# Getting top 5 recommendations for user_id rLtl8ZkDX5vH5nAx9C3q5Q using "svd_optimized" algorithm
svd_recommendations = get_recommendations(df_final, "rLtl8ZkDX5vH5nAx9C3q5Q", 5, svd_optimized)

# %%
# Ranking products based on above recommendations
ranking_products(svd_recommendations, final_rating)
# Out:
#               business_id  rating_count  predicted_ratings  corrected_ratings
# 1  X3icXUyW9vS4UXY6V_MR4w            79           4.764319           4.651811
# 0  GwSdGrvaXi4BdXNSWKn-EA           153           4.645138           4.564293
# 2  97Z7j4vH0kfzL10AONi4uA            78           4.637496           4.524268
# 3  XRBTHOXaJK_AJ2wy5mX_1A            26           4.622570           4.426454
# 4  4SviSw8uRF0ddj_HxUVnuA            10           4.623874           4.307647

# %% [markdown]
# #### ALS

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# In this case study, we built recommendation systems using five different algorithms. They are as follows:
# - rank-based using averages
# - User-user-similarity-based collaborative filtering
# - Item-item-similarity-based collaborative filtering
# - model-based (matrix factorization) collaborative filtering
# - SVD using ALS (Least Squares)
#
#
# - We have seen how they are different from each other and what kind of data is needed to build each of these recommendation systems. We can further combine all the recommendation techniques we have seen.
# - To demonstrate **"user-user-similarity-based collaborative filtering","item-item-similarity-based collaborative filtering", and "model-based (matrix factorization) collaborative filtering"**, **surprise** library has been introduced. For these algorithms **grid search cross-validation is applied to find the best working model**, and using that the **corresponding predictions are done**.
#
# - **For performance evaluation** of these models **precision@k and recall@k** are introduced in this case study. Using these two metrics **F_1 score** is calculated for each working model.
